# %%
#Pandas Series 만들기
#판다스 시리즈 변수는 파이썬의 딕셔너리 구조와 비슷하여 딕셔너리를 시리즈로 변환하는 방법을 많이 사용한다

#딕셔너리를 시리즈 변수로 변환하기
# 시리즈변수 = 판다스모듈.Series(딕셔너리변수)

#pandas 모듈 불러오기
import pandas as pd

#딕셔너리 선언
dict_data = {
    "key1":"data1",
    "key2":"data2",
    "key3":"data3"
}

#Series 함수로 딕셔너리를 시리즈형태로 변환
series_data = pd.Series(dict_data)

#Series 변수 자료형 출력
print(type(series_data))

#Series 변수 출력
print(series_data)
# Out:
# <class 'pandas.core.series.Series'>
# key1    data1
# key2    data2
# key3    data3
# dtype: object

# %%
#index 구조
#인덱스는 자기와 짝을 이루는 데이터 값의 순서와 주소를 저장한다.
#인덱스를 잘 활용 하면 데이터 값의 탐색,정렬,선택,결합 등 데이터 조작을 쉽게 할 수 있다

#시리즈 인덱스 배열 추출
#시리즈데이터.index

#시리즈 데이터 배열 추출
#시리즈데이터.values

#pandas 모듈 불러오기
import pandas as pd

#리스트 데이터를 시리즈로 변환하여 저장
list_data = ["2019-01-02", 3.14, "ABC", 100, True]
series_data = pd.Series(list_data)

#인덱스 배열은 변수 index_array에, 데이터 베열은 변수 data_array에 저장
index_array = series_data.index
data_array =series_data.values

print("index_array:",index_array)
print("data_array:",data_array)
# Out:
# index_array: RangeIndex(start=0, stop=5, step=1)
# data_array: ['2019-01-02' 3.14 'ABC' 100 True]

# %%
#원소 선택
#원소의 위치를 나타내는 주소 역할을 하는 인덱스를 이용하여 시리즈 원소를 선택한다
#리스트나 튜플 같이 딕셔너리의 키에 해당 되는 부분이 없는 데이터를 시리즈로 변환 할 때
#그냥 변환하면 정수 인덱스가 부여 되지만 직접 인덱스명을 부여 할 수 있다.

#pandas 모듈 불러오기
import pandas as pd

#tuple데이터를 시리즈로 변환, index매개 변수 입력하여 인덱스명 직접 부여 가능
tup_data = ("영인", "2010-05-01", "여", True)
series_data = pd.Series(tup_data, index=["이름","생년월일","성별","학생여부"])
print(series_data)
print("--------------------------------")
#원소 1개 선택
#정수 인덱스로 선택
print(series_data[0])
#인덱스명으로 선택
print(series_data["이름"])

#여러개 원소 선택
#리스트 형식으로 정수형 으로 선택
print(series_data[[1,2]])
#리스트 형식으로 인덱스명 으로 선택
print(series_data[["생년월일","성별"]])

#원소를 특정 범위로 불러오기
#정수형 인덱스로 범위로 찾기,[a:b]로 지정하면 a ~ (b - 1)의 범위로 찾는다
print(series_data[1:2])
#인덱스명으로 범위로 찾기, [a:b]로 지정하면 a ~ b 의 범위로 찾는다.
print(series_data["생년월일":"성별"])
# Out:
# 이름              영인
# 생년월일    2010-05-01
# 성별               여
# 학생여부          True
# dtype: object
# --------------------------------
# 영인
# 영인
# 생년월일    2010-05-01
# 성별               여
# dtype: object
# 생년월일    2010-05-01
# 성별               여
# dtype: object

# %%
#데이터 프레임
#데이터 프레임은 2차원 배열이다. 행과 열로 만들어 지는 2차원 배열 구조는 
#MS 엑셀이나 데이터베이트 등 컴퓨터 관련 분야에서 다양하게 사용하고 있다

# 행 : 가로, Row, index
# 열 : 세로, Column, Data

#데이터 프레임 만들기
# 딕셔너리 -> 데이터프레임 변환
# 데이터프레임 = 판다스모듈.DataFrame(딕셔너리)

#pandas 모듈 불러오기
import pandas as pd

#딕셔너리 선언
dict_data = {
    "c0":[1,2,3],
    "c1":[4,5,6],
    "c2":[7,8,9],
    "c3":[10,11,12],
    "c3":[13,14,15],
}

#판다스 DataFrame() 함수로 딕셔너리를 데이터 프레임 형식으로 변환
df = pd.DataFrame(dict_data)
print("데이터프레임 원본")
print(df)
print("\n")

#데이터 프레임 자료형 출력
print(type(df))

#데이터프레임 객체 출력
print(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    c0  c1  c2  c3
# 0   1   4   7  13
# 1   2   5   8  14
# 2   3   6   9  15

# %%
#행 인덱스 / 열 이름 설정
#데이터 프레임 구조적 특성 상 2차원 배열 형태의 데이터를 데이터 프레임으로 변환하기 쉽다.
#2차원 배열에는 여러개 리스트(또는 투플)를 원소로 갖는 리스트(또는 투플)를 예로 들 수 있다

#한편 2차원 배열을 DataFrame()함수 인자로 전달하여 데이터 프레임으로 변환 할 때 
#행 인덱스와 열 이름 속성을 사용자가 직접 설정 할 수 있다.

#행 인덱스 이름 설정
# 판다스모듈.DataFrame(2차원배열, index=행인덱스 배열, columne=열이름 배열)

#pandas 모듈 불러오기
import pandas as pd

#행 인덱스 배열 / 열 이름 지정하여 데이터 프레임 만들기
df = pd.DataFrame(
    [
        [15,"남","덕영중"],
        [17,"여","수리중"]
    ],
    index=["준서","예은"],
    columns=["나이","성별","학교"]
)
print("데이터프레임 원본")
print(df)
print("\n")

#객체 출력
print(df)

# 행 인덱스
print(df.index)

# 열 이름
print(df.values)

#행 인덱스 / 열 이름 변경하기
#데이터 프레임 접근과 같은 방식으로 데이터 수정하는 방식으로 변경이 가능하다
df.index = ["학생1", "학생2"]
df.columns=["연령","남녀","소속"]
print(df.index)
print(df.values)
# Out:
#     나이 성별   학교
# 준서  15  남  덕영중
# 예은  17  여  수리중
# Index(['준서', '예은'], dtype='object')
# [[15 '남' '덕영중']
#  [17 '여' '수리중']]
#      연령 남녀   소속
# 학생1  15  남  덕영중
# 학생2  17  여  수리중
#
#
# Index(['학생1', '학생2'], dtype='object')
#
#
# [[15 '남' '덕영중']
#  [17 '여' '수리중']]

# %%
# 행 인덱스 / 열 이름 변경
#rename() 메소드 사용하여 일부만 변경 할 수도 있다
#단 원본 객체를 직접 수정 하는게 아니라 새로운 객체에 임시로 변경 한 사항이라
#적용하려면 inplace=Ture 옵션을 적용 해줘야 한다

#pandas 모듈 불러오기
import pandas as pd

#행 인덱스 배열 / 열 이름 지정하여 데이터 프레임 만들기
df = pd.DataFrame(
    [
        [15,"남","덕영중"],
        [17,"여","수리중"]
    ],
    index=["준서","예은"],
    columns=["나이","성별","학교"]
)
print("데이터프레임 원본")
print(df)
print("\n")

#열 이름 중 나이를 연령으로, 성별을 남녀로, 학교를 소속으로 변경
df.rename(columns = {"나이":"연령","성별":"남녀","학교":"소속" }, inplace=True)

#행 인덱스 중에서 준서를 학생1로, 예은을 학생2로 변경
df.rename(index = {"준서":"학생1","예은":"학생2"}, inplace=True)
# Out:
#      연령 남녀   소속
# 학생1  15  남  덕영중
# 학생2  17  여  수리중

# %%
#행/열 삭제
# 데이터프레임의 행 또는 열을 삭제하는 함수로 drop()메소드가 있다
# 행을 삭제할때 옵션으로 axis=0을 열을 삭제 할때는 axis=1로 선택.
# 적용 하려면 inplase=True 옵션을 넣어 줘야 한다.

#행삭제 :데이터프레임.drop(행인덱스, axis=0, inplase=True)
#열삭제 :데이터프레임.drop(열 이름, axis=0, inplase=True)

import pandas as pd

#데이터프레임 생성
dict_data = {
    '수학':[90,80,70],
    '영어':[98,89,95],
    '음악':[85,95,100],
    '체육':[100,90,90]
}
df = pd.DataFrame(dict_data, index=["서준","우현","인아"])
print("데이터프레임 원본")
print(df)
print("\n")

#행(row) 1개 삭제.
#새로운 데이터 프레임에 복제. 원본 보호 조치
df_deletrow_2 = df.copy()
df_deletrow_2.drop("우현", axis=0,inplace=True)

#행(row) 2개 삭제.
df_deletrow_2 = df.copy()
df_deletrow_2.drop(["우현","인아"], axis=0, inplace=True)

#열(columns) 1개 삭제
df_deletcolumn_2 = df.copy()
df_deletcolumn_2.drop("수학", axis=1,inplace=True)

#열(columns) 2개 삭제
df_deletcolumn_2 = df.copy()
df_deletcolumn_2.drop(["영어","음악"], axis=1, inplace=True)
# Out:
# ----행 1개 삭제----
#     수학  영어   음악   체육
# 서준  90  98   85  100
# 인아  70  95  100   90
# ----행 2개 삭제----
#     수학  영어  음악   체육
# 서준  90  98  85  100
# ----열 1개 삭제----
#     영어   음악   체육
# 서준  98   85  100
# 우현  89   95   90
# 인아  95  100   90
# ----열 1개 삭제----
#     수학   체육
# 서준  90  100
# 우현  80   90
# 인아  70   90

# %%
#행 선택
#데이터 프레임의 행 데이터를 선택하기 위해서 loc와 iloc 인덱서를 사용한다.
#인덱스 이름을 기준으로 행을 선택할때는 loc 사용
#정수형 인덱스오 행을 선택할때는 iloc를 사용

# 탐색 범위
#loc : loc[a:c] -> a,b,c
#iloc : iloc[3:7] -> 3,4,5,6

import pandas as pd
#데이터프레임 생성
dict_data = {
    '수학':[90,80,70],
    '영어':[98,89,95],
    '음악':[85,95,100],
    '체육':[100,90,90]
}
df = pd.DataFrame(dict_data, index=["서준","우현","인아"])
print("데이터프레임 원본")
print(df)
print("\n")

#행인덱스 사용하여 행 1개 선택
label = df.loc["서준"]
position = df.iloc[0]

#2개이상의 행 선택
label = df.loc[["서준","우현"]]
position = df.iloc[[0,1]]

# 범위 선택
label = df.loc["서준":"우현"]
position = df.iloc[0:1]
# Out:
# df.loc["서준"]
# 수학     90
# 영어     98
# 음악     85
# 체육    100
# Name: 서준, dtype: int64
# df.iloc[0]
# 수학     90
# 영어     98
# 음악     85
# 체육    100
# Name: 서준, dtype: int64
# df.loc[["서준","우현"]]
#     수학  영어  음악   체육
# 서준  90  98  85  100
# 우현  80  89  95   90
# df.iloc[[0,1]]
#     수학  영어  음악   체육
# 서준  90  98  85  100
# 우현  80  89  95   90
# df.loc["서준":"우현"]
#     수학  영어  음악   체육
# 서준  90  98  85  100
# 우현  80  89  95   90
# df.iloc[0:1]
#     수학  영어  음악   체육
# 서준  90  98  85  100

# %%
#열 선택
#데이터 프레임에서 열 선택은 두가지 방식이 있다
#데이터프레임.열이름
#데이터프레임["열이름"]

#다중 선택시 리스트형으로 선택하면 된다
#데이터프레임[["열이름","열이름", ... ,"열이름"]]

import pandas as pd

#데이터프레임 생성
dict_data = {
    '이름':["서준","우현","인아"],
    '수학':[90,80,70],
    '영어':[98,89,95],
    '음악':[85,95,100],
    '체육':[100,90,90]
}
df = pd.DataFrame(dict_data)
print("데이터프레임 원본")
print(df)
print("\n")

#수학 점수만 선택
math_score = df["수학"]

#영어 점수만 선택
english_score = df["영어"]

#2개 이상 점수 출력
multi_score = df[["수학","영어"]]
# Out:
# 0    90
# 1    80
# 2    70
# Name: 수학, dtype: int64
# 0    98
# 1    89
# 2    95
# Name: 영어, dtype: int64
#    수학  영어
# 0  90  98
# 1  80  89
# 2  70  95

# %%
# 원소 선택
#인덱스이름 : 데이터프레임.loc[행인덱스,열이름]
#정수형 인덱스 : 데이터프레임.iloc[행번호, 열번호]

#판다스 모듈 추가
import pandas as pd

#데이터프레임 생성
dict_data = {
    '이름':["서준","우현","인아"],
    '수학':[90,80,70],
    '영어':[98,89,95],
    '음악':[85,95,100],
    '체육':[100,90,90]
}
df = pd.DataFrame(dict_data)
print("데이터프레임 원본")
print(df)
print("\n")

#"이름"열을 새로운 인덱스로 지정하고 df객체에 변경사항 적용
df.set_index("이름",inplace=True)

#데이터 프레임 df의 특정 원소 1개 선택 (서준의 음악 점수)
a = df.loc["서준","음악"]
b = df.iloc[0,2]

#데이터 프레임 df의 특정 원소 1개 선택 (서준의 음악 체육 점수)
a = df.loc["서준",["음악","체육"]]
b = df.iloc[0,[2,3]]

#데이터프레임 원소를 선택할 때 행 인덱스와 영 이름을 각각 2개 이상 선택하여 데이터 프레임 정보 얻기
a = df.loc[["서준","우현"],["음악","체육"]]
b = df.iloc[[0,1],[2,3]]
# Out:
#     수학  영어   음악   체육
# 이름
# 서준  90  98   85  100
# 우현  80  89   95   90
# 인아  70  95  100   90
# 85
# 85
# 음악     85
# 체육    100
# Name: 서준, dtype: int64
# 음악     85
# 체육    100
# Name: 서준, dtype: int64
#     음악   체육
# 이름
# 서준  85  100
# 우현  95   90
#     음악   체육
# 이름
# 서준  85  100
# 우현  95   90

# %%
#열 추가
#추가하려는 열 이름과 데이터 값을 다음과 같은 형식으로 추가. 데이터 프레임의 마지막 열에 덧붙이듯 추가한다
#데이터프레임객체[추가 하려는 열 이름] = 데이터 값

#판다스 모듈 추가
import pandas as pd

#데이터프레임 생성
dict_data = {
    '이름':["서준","우현","인아"],
    '수학':[90,80,70],
    '영어':[98,89,95],
    '음악':[85,95,100],
    '체육':[100,90,90]
}
df = pd.DataFrame(dict_data)
print("데이터프레임 원본")
print(df)
print("\n")

#데이터 프레임에 '국어'점수 열(Column) 새로 추가. 데이터 값은 80으로 
df["국어"] = 80
# Out:
#    이름  수학  영어   음악   체육  국어
# 0  서준  90  98   85  100  80
# 1  우현  80  89   95   90  80
# 2  인아  70  95  100   90  80

# %%
#행 추가
#데이터 프레임에 새로운 행을 추가할 때는 기존 행 인덱스와 겹치지 않는 새로운 인덱스를 사용
#기존 인덱스와 겹치게 되면 추가하는 것이 아닌 교체하게 되기 때문이다.
#데이터프레임객체.loc[새로운 행 이름] = 데이터 값

#판다스 모듈 추가
import pandas as pd

#데이터프레임 생성
dict_data = {
    '이름':["서준","우현","인아"],
    '수학':[90,80,70],
    '영어':[98,89,95],
    '음악':[85,95,100],
    '체육':[100,90,90]
}
df = pd.DataFrame(dict_data)
print("데이터프레임 원본")
print(df)
print("\n")

#새로운 행 (row)추가, 같은 값 입력
df.loc[3] = 0

#새로운 행 추가, 원소 값 여러 개의 배열 입력
df.loc[4] = ["동규", 90, 80, 70, 60]

#새로운 행 추가, 기존 행 복사
df.loc["행5"] = df.loc[3]
# Out:
# 새로운 행 추가, 같은 값 입력
#    이름  수학  영어   음악   체육
# 0  서준  90  98   85  100
# 1  우현  80  89   95   90
# 2  인아  70  95  100   90
# 3   0   0   0    0    0
# 새로운 행 추가, 원소 값 여러 개의 배열 입력
#    이름  수학  영어   음악   체육
# 0  서준  90  98   85  100
# 1  우현  80  89   95   90
# 2  인아  70  95  100   90
# 3   0   0   0    0    0
# 4  동규  90  80   70   60
# 새로운 행 추가, 기존 행 복사
#     이름  수학  영어   음악   체육
# 0   서준  90  98   85  100
# 1   우현  80  89   95   90
# 2   인아  70  95  100   90
# 3    0   0   0    0    0
# 4   동규  90  80   70   60
# 행5   0   0   0    0    0

# %%
#원소 값 변경
#데이터프레임의 특정 온소를 선택하고 새로운 데이터 값을 지정 해 주면원소 값이 변경된다.
#원소 1개를 선택하여 변경 할 수도 있고 여러개의 원소를 선택하여 한꺼번에 값을 바꿀 수도 있다

#데이터프레임 객체의 일부분 또는 원소 선택 = 새로운 값

#판다스 모듈 추가
import pandas as pd

#데이터프레임 생성
dict_data = {
    '이름':["서준","우현","인아"],
    '수학':[90,80,70],
    '영어':[98,89,95],
    '음악':[85,95,100],
    '체육':[100,90,90]
}
df = pd.DataFrame(dict_data)
print("데이터프레임 원본")
print(df)
print("\n")

#"이름" 열을 새로운 인덱스로 지정 하고 데이터프레임 객체에 변경 사항 적용
df.set_index("이름",inplace=True)

#데이터 프레임의 특정 원소를 변경하는 방법 : "서준"의 "체육"점수 변경
df.iloc[0][3] = 80
df.loc["서준"]["체육"] = 90
df.loc["서준","체육"] = 100

#데이터 프레임의 원소 여러개를 변경 하는 방법 : "서준"의 "음악"과 "체육"점수 변경
df.loc["서준",["음악","체육"]] = 100, 50

# %%
#행 열의 위치 바꾸기
#데이터 프레임의 행과 열을 바꾸는 방법이다

#데이터 프레임 객체.transpose()
#데이터 프레임 객체.T

#판다스 모듈 추가
import pandas as pd

#데이터프레임 생성
dict_data = {
    '이름':["서준","우현","인아"],
    '수학':[90,80,70],
    '영어':[98,89,95],
    '음악':[85,95,100],
    '체육':[100,90,90]
}
df = pd.DataFrame(dict_data)
print("데이터프레임 원본")
print(df)
print("\n")

#데이터 프레임 전치하기
df=df.transpose()
print(df)

#데이터 프레임 다시 전치하기
df=df.T
print(df)

# %%
#인덱스 활용
#set_index() 메소드를 사용하여 데이터프레임의 특정열을 행 인덱스로 설정
#원본을 변경 하는게 아닌 새로운 데이터프레임을 반환하는 점에서 유의

#특정 열을 행 인덱스로 설정
#데이터프레임 객체.set_index(["열 이름" 또는 "열 이름"])

#판다스 모듈 추가
import pandas as pd

#데이터프레임 생성
dict_data = {
    '이름':["서준","우현","인아"],
    '수학':[90,80,70],
    '영어':[98,89,95],
    '음악':[85,95,100],
    '체육':[100,90,90]
}
df = pd.DataFrame(dict_data)
print("데이터프레임 원본")
print(df)
print("\n")

#특정 열(column)을 데이터프레임의 행 인덱스로 설정
new_index_df = df.set_index("이름")
print("데이터프레임 원본에서 \'이름\'을 인덱스로 설정")
print(new_index_df)
print("\n")

#특정 열(column)을 데이터프레임의 행 인덱스로 설정
new_index_df = df.set_index("음악")
print("데이터프레임 원본에서 \'음악\'을 인덱스로 설정")
print(new_index_df)
print("\n")

#특정 열(column)을 데이터프레임의 행 인덱스로 설정
new_index_df = df.set_index(["수학","음악"])
print("데이터프레임 원본에서 \'수학\',\'음악\' 을 인덱스로 설정")
print(new_index_df)
print("\n")
# Out:
# 데이터프레임 원본
#    이름  수학  영어   음악   체육
# 0  서준  90  98   85  100
# 1  우현  80  89   95   90
# 2  인아  70  95  100   90
#
#
# 데이터프레임 원본에서 '이름'을 인덱스로 설정
#     수학  영어   음악   체육
# 이름
# 서준  90  98   85  100
# 우현  80  89   95   90
# 인아  70  95  100   90
#
#
# 데이터프레임 원본에서 '음악'을 인덱스로 설정
#      이름  수학  영어   체육
# 음악
# 85   서준  90  98  100
# 95   우현  80  89   90
# 100  인아  70  95   90
#
#
# 데이터프레임 원본에서 '수학','음악' 을 인덱스로 설정
#         이름  영어   체육
# 수학 음악
# 90 85   서준  98  100
# 80 95   우현  89   90
# 70 100  인아  95   90

# %%
#행 인덱스 재배열
#reindex() 메소드를 사용하면 데이터프레임의 행 인덱스를 새로운 배열로 재지정 할 수 있다

#새로운 배열로 행 인덱스를 재지정
#데이터 프레임 객체를 지정.reindex(새로운 인덱스 배열)

#판다스 모듈 추가
import pandas as pd

#데이터프레임 생성
dict_data = {
    "c0" : [1,2,3],
    "c1" : [4,5,6],
    "c2" : [7,8,9],
    "c3" : [10,11,12],
    "c4" : [13,14,15]
}

#딕셔너리를 데이터프레임으로 변환, 인덱스를 ["r0","r1","r2"]
df=pd.DataFrame(dict_data, index=["r0","r1","r2"])
print("딕셔너리를 데이터프레임으로 변환")
print(df)
print("\n")

#인덱스를 ["r0","r1","r2","r3","r4"]로 재지정
new_index = ["r0","r1","r2","r3","r4"]
ndf = df.reindex(new_index)
print("인덱스를 재지정")
print(ndf)
print("\n")

#새로운 인덱스 추가로 인하여 Null Data (NaN)를 채우기
new_index = ["r0","r1","r2","r3","r4"]
ndf = df.reindex(new_index, fill_value=0)
print("인덱스를 재지정 후 데이터 채우기")
print(ndf)
print("\n")
# Out:
# 딕셔너리를 데이터프레임으로 변환
#     c0  c1  c2  c3  c4
# r0   1   4   7  10  13
# r1   2   5   8  11  14
# r2   3   6   9  12  15
#
#
# 인덱스를 재지정
#      c0   c1   c2    c3    c4
# r0  1.0  4.0  7.0  10.0  13.0
# r1  2.0  5.0  8.0  11.0  14.0
# r2  3.0  6.0  9.0  12.0  15.0
# r3  NaN  NaN  NaN   NaN   NaN
# r4  NaN  NaN  NaN   NaN   NaN
#
#
# 인덱스를 재지정 후 데이터 채우기
#     c0  c1  c2  c3  c4
# r0   1   4   7  10  13
# r1   2   5   8  11  14
# r2   3   6   9  12  15
# r3   0   0   0   0   0
# r4   0   0   0   0   0

# %%
#행 인덱스 초기화
#reset_index() 메소드를 활용하여 행 인덱스를 정수형 위치 인덱스로 초기화한다.

#정수 위치 인덱스로 초기화
#데이터 프레임 객체.reset_index()

#판다스 모듈 추가
import pandas as pd

#데이터프레임 생성
dict_data = {
    "c0" : [1,2,3],
    "c1" : [4,5,6],
    "c2" : [7,8,9],
    "c3" : [10,11,12],
    "c4" : [13,14,15]
}

#딕셔너리를 데이터프레임으로 변환, 인덱스를 ["r0","r1","r2"]
df=pd.DataFrame(dict_data, index=["r0","r1","r2"])
print("딕셔너리를 데이터프레임으로 변환")
print(df)
print("\n")

#행 인덱스를 정수형 인덱스로 초기화
df = df.reset_index()
print("행 인덱스를 정수형 인덱스로 초기화")
print(df)
print("\n")
# Out:
# 딕셔너리를 데이터프레임으로 변환
#     c0  c1  c2  c3  c4
# r0   1   4   7  10  13
# r1   2   5   8  11  14
# r2   3   6   9  12  15
#
#
# 행 인덱스를 정수형 인덱스로 초기화
#   index  c0  c1  c2  c3  c4
# 0    r0   1   4   7  10  13
# 1    r1   2   5   8  11  14
# 2    r2   3   6   9  12  15

# %%
# 행 인덱스를 기준으로 데이터프레임 정렬
# sort_index() 메소드를 활용하여 행 인덱스를 기준으로 데이터 프레임의 값을 정렬한다
# ascending 옵션을 사용하여 오름/내림 차순으로 정렬
# ascending=True -> 오름차순
# ascending=False -> 내림차순

#행 인덱스를 기준으로 데이터 프레임 정렬
#데이터프레임 객체.sort_index()

#판다스 모듈 추가
import pandas as pd

#데이터프레임 생성
dict_data = {
    "c0" : [1,2,3],
    "c1" : [4,5,6],
    "c2" : [7,8,9],
    "c3" : [10,11,12],
    "c4" : [13,14,15]
}

#딕셔너리를 데이터프레임으로 변환, 인덱스를 ["r0","r1","r2"]
df=pd.DataFrame(dict_data, index=["r0","r1","r2"])
print("딕셔너리를 데이터프레임으로 변환")
print(df)
print("\n")

#행 인덱스를 내림차순으로 정렬
ndf = df.sort_index(ascending=False)
print("행 인덱스를 내림차순으로 정렬")
print(ndf)
print("\n")

#행 인덱스를 오름차순으로 정렬
ndf = df.sort_index(ascending=True)
print("행 인덱스를 오름차순으로 정렬")
print(ndf)
print("\n")
# Out:
# 딕셔너리를 데이터프레임으로 변환
#     c0  c1  c2  c3  c4
# r0   1   4   7  10  13
# r1   2   5   8  11  14
# r2   3   6   9  12  15
#
#
# 행 인덱스를 내림차순으로 정렬
#     c0  c1  c2  c3  c4
# r2   3   6   9  12  15
# r1   2   5   8  11  14
# r0   1   4   7  10  13
#
#
# 행 인덱스를 오름차순으로 정렬
#     c0  c1  c2  c3  c4
# r0   1   4   7  10  13
# r1   2   5   8  11  14
# r2   3   6   9  12  15

# %%
# 열 데이터 값을 기준으로 데이터프레임 정렬
# 데이터프레임 객체,sort_values()
# ascending 옵션을 사용하여 오름/내림 차순으로 정렬
# ascending=True -> 오름차순
# ascending=False -> 내림차순

#판다스 모듈 추가
import pandas as pd

#데이터프레임 생성
dict_data = {
    "c0" : [1,2,3],
    "c1" : [4,5,6],
    "c2" : [7,8,9],
    "c3" : [10,11,12],
    "c4" : [13,14,15]
}

#딕셔너리를 데이터프레임으로 변환, 인덱스를 ["r0","r1","r2"]
df=pd.DataFrame(dict_data, index=["r0","r1","r2"])
print("딕셔너리를 데이터프레임으로 변환")
print(df)
print("\n")

#열 데이터를 내림차순으로 정렬
ndf = df.sort_values(by="c1",ascending=False)
print("열 데이터를 내림차순으로 정렬")
print(ndf)
print("\n")

#열 데이터를 오름차순으로 정렬
ndf = df.sort_values(by="c1",ascending=True)
print("열 데이터를 오름차순으로 정렬")
print(ndf)
print("\n")
# Out:
# 딕셔너리를 데이터프레임으로 변환
#     c0  c1  c2  c3  c4
# r0   1   4   7  10  13
# r1   2   5   8  11  14
# r2   3   6   9  12  15
#
#
# 열 데이터를 내림차순으로 정렬
#     c0  c1  c2  c3  c4
# r2   3   6   9  12  15
# r1   2   5   8  11  14
# r0   1   4   7  10  13
#
#
# 열 데이터를 오름차순으로 정렬
#     c0  c1  c2  c3  c4
# r0   1   4   7  10  13
# r1   2   5   8  11  14
# r2   3   6   9  12  15

# %%
#시리즈연산
#시리즈 객체에 어떤 숫자를 더하면 시리즈 개별 원소에 각각 숫자를 더하고 계산한 결과를 시리즈 객체로 반환한다.
#사칙연산 가능
#시리즈 객체 + 연산자 + 숫자

#판다스 모듈 추가
import pandas as pd

#딕셔너리 데이터로 판다스 시리즈 만들기
series_data = pd.Series(
    {
        "국어" : 100,
        "영어" : 80,
        "수학" : 90
    }
)
print("딕셔너리 데이터로 판다스 시리즈 만들기")
print(series_data)
print("\n")

#학생의 과목별 점수를 200으로 나누기
div_score = series_data / 200

print("학생의 과목별 점수를 200으로 나누기")
print(div_score)
print("\n")
# Out:
# 딕셔너리 데이터로 판다스 시리즈 만들기
# 국어    100
# 영어     80
# 수학     90
# dtype: int64
#
#
# 학생의 과목별 점수를 200으로 나누기
# 국어    0.50
# 영어    0.40
# 수학    0.45
# dtype: float64

# %%
#시리즈 끼리 연산
#시리즈와 시리즈 사이에 사칙연산을 처리하는 방법이다.

# 시리즈객체 + 연산자 + 시리즈객체

#판다스 모듈 추가
import pandas as pd

#딕셔너리 데이터로 판다스 시리즈 만들기
series_data_1 = pd.Series(
    {
        "국어" : 100,
        "영어" : 80,
        "수학" : 90
    }
)

series_data_2 = pd.Series(
    {
        "국어" : 80,
        "영어" : 90,
        "수학" : 80
    }
)
print("딕셔너리 데이터로 판다스 시리즈 만들기")
print("Series_1")
print(series_data_1)
print("\n")
print("Series_2")
print(series_data_2)
print("\n")

#두 시리그 객체의 과목별 점수로 사칙연산
add_res = series_data_1 + series_data_2
print("덧셈 결과")
print(add_res)
print("\n")

sud_res = series_data_1 - series_data_2
print("뺄셈 결과")
print(add_res)
print("\n")

mul_res = series_data_1 * series_data_2
print("곱셈 결과")
print(mul_res)
print("\n")

div_res = series_data_1 / series_data_2
print("나눗셈 결과")
print(div_res)
print("\n")
# Out:
# 딕셔너리 데이터로 판다스 시리즈 만들기
# Series_1
# 국어    100
# 영어     80
# 수학     90
# dtype: int64
#
#
# Series_2
# 국어    80
# 영어    90
# 수학    80
# dtype: int64
#
#
# 덧셈 결과
# 국어    180
# 영어    170
# 수학    170
# dtype: int64
#
#
# 뺄셈 결과
# 국어    180
# 영어    170
# 수학    170
# dtype: int64
#
#
# 곱셈 결과
# 국어    8000
# 영어    7200
# 수학    7200
# dtype: int64
#
#
# 나눗셈 결과
# 국어    1.250000
# 영어    0.888889
# 수학    1.125000
# dtype: float64

# %%
# NaN값이 있는 시리즈 객체 연산
# 시리즈 끼리 연산 할 때 한쪽에 없는 인덱스나 인덱스가 있어도 NaN값인 상태로 연산 할때 판다스에서는 결과를 NaN으로 출력한다.

#판다스 모듈 추가
import pandas as pd

#numpy 모듈 추가
import numpy as np

#딕셔너리 데이터로 판다스 시리즈 만들기
series_data_1 = pd.Series(
    {
        "국어" : np.nan,
        "영어" : 80,
        "수학" : 90
    }
)

series_data_2 = pd.Series(
    {
        "수학" : 80,
        "국어" : 90
    }
)
print("딕셔너리 데이터로 판다스 시리즈 만들기")
print("Series_1")
print(series_data_1)
print("\n")
print("Series_2")
print(series_data_2)
print("\n")

#두 시리즈 객체의 과목별 점수 사칙연산 수행
add_res = series_data_1 + series_data_2
print("덧셈 결과")
print(add_res)
print("\n")

sud_res = series_data_1 - series_data_2
print("뺄셈 결과")
print(add_res)
print("\n")

mul_res = series_data_1 * series_data_2
print("곱셈 결과")
print(mul_res)
print("\n")

div_res = series_data_1 / series_data_2
print("나눗셈 결과")
print(div_res)
print("\n")
# Out:
# 딕셔너리 데이터로 판다스 시리즈 만들기
# Series_1
# 국어     NaN
# 영어    80.0
# 수학    90.0
# dtype: float64
#
#
# Series_2
# 수학    80
# 국어    90
# dtype: int64
#
#
# 덧셈 결과
# 국어      NaN
# 수학    170.0
# 영어      NaN
# dtype: float64
#
#
# 뺄셈 결과
# 국어      NaN
# 수학    170.0
# 영어      NaN
# dtype: float64
#
#
# 곱셈 결과
# 국어       NaN
# 수학    7200.0
# 영어       NaN
# dtype: float64
#
#
# 나눗셈 결과
# 국어      NaN
# 수학    1.125
# 영어      NaN
# dtype: float64

# %%
#연산 메소드 활용
#단순 사칙연산 기호를 사용하게 되면 NaN 데이터가 있는 인덱스나 공용된 인덱스가 없는 부분은 NaN으로 반환된다.
#이때 연산 메소드를 사용하여 옵션에 fill_value를 사용하여 NaN 대신 채울 데이터를 지정 해 줄 수 있다

#연산 메소드 사용(시리즈와 시리즈 연산)
#시리즈 객체.연산메소드(시리즈 객체, fill_value=NaN 대신 채울 데이터)

#판다스 모듈 추가
import pandas as pd

#numpy 모듈 추가
import numpy as np

#딕셔너리 데이터로 판다스 시리즈 만들기
series_data_1 = pd.Series(
    {
        "국어" : np.nan,
        "영어" : 80,
        "수학" : 90
    }
)

series_data_2 = pd.Series(
    {
        "수학" : 80,
        "국어" : 90
    }
)
print("딕셔너리 데이터로 판다스 시리즈 만들기")
print("Series_1")
print(series_data_1)
print("\n")
print("Series_2")
print(series_data_2)
print("\n")

#두 시리즈 객체의 과목별 점수 연산 메소드 사용, NaN을 0으로 채우기
add_res = series_data_1.add(series_data_2, fill_value=0 )
print("덧셈 결과")
print(add_res)
print("\n")

sud_res = series_data_1.sub(series_data_2, fill_value=0 )
print("뺄셈 결과")
print(add_res)
print("\n")

mul_res = series_data_1.mul(series_data_2, fill_value=0 )
print("곱셈 결과")
print(mul_res)
print("\n")

div_res = series_data_1.div(series_data_2, fill_value=0 )
print("나눗셈 결과")
print(div_res)
print("\n")
# Out:
# 딕셔너리 데이터로 판다스 시리즈 만들기
# Series_1
# 국어     NaN
# 영어    80.0
# 수학    90.0
# dtype: float64
#
#
# Series_2
# 수학    80
# 국어    90
# dtype: int64
#
#
# 덧셈 결과
# 국어     90.0
# 수학    170.0
# 영어     80.0
# dtype: float64
#
#
# 뺄셈 결과
# 국어     90.0
# 수학    170.0
# 영어     80.0
# dtype: float64
#
#
# 곱셈 결과
# 국어       0.0
# 수학    7200.0
# 영어       0.0
# dtype: float64
#
#
# 나눗셈 결과
# 국어    0.000
# 수학    1.125
# 영어      inf
# dtype: float64

# %%
#데이터프레임 vs 숫자
#데이터프레임 객체에 어떤 숫자를 더하면 모든 원소에 덧셈을 적용한다. 사칙연산 가능

#데이터 프레임과 숫자 연산
#데이터플로우 객체 + 연산자 + 숫자

#판다스 모듈 추가
import pandas as pd

#데이터 세트 추가
import seaborn as sns

#titanic 탑승객 정보 "나이", "구조여부" 데이터 불러오기
titanic_data = sns.load_dataset("titanic")
df=titanic_data.loc[:,["age","fare"]]
print("titanic data")
print(df.head())
print("\n")
print("titanic data type")
print(type(df))
print("\n")

#데이터 프레임에 덧셈 연산
add_res = df + 10
print("titanic data add int 10")
print(add_res.head())
print("\n")
print("titanic data add int 10")
print(type(add_res))
print("\n")
# Out:
# titanic data
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500
#
#
# titanic data type
# <class 'pandas.core.frame.DataFrame'>
#
#
# titanic data add int 10
#     age     fare
# 0  32.0  17.2500
# 1  48.0  81.2833
# 2  36.0  17.9250
# 3  45.0  63.1000
# 4  45.0  18.0500
#
#
# titanic data add int 10
# <class 'pandas.core.frame.DataFrame'>

# %%
#데이터 프레임 끼리 연산
#각 데이터 프레임의 같은 행,열 위치에 있는 연소끼리 연산한다. 
#동일한 위치의 원소끼리 연산 실행 하고 어느 한쪽에 원소가 존재하지 않거나 NaN가 있으면 결과를 NsN으로 반환한다.

#데이터 프레임끼리 연산
#데이터프레임 객체 + 연산자 + 데이터프레임 객체

#판다스 모듈 추가
import pandas as pd

#데이터 세트 추가
import seaborn as sns

#titanic 탑승객 정보 "나이", "구조여부" 데이터 불러오기
titanic_data = sns.load_dataset("titanic")
df=titanic_data.loc[:,["age","fare"]]
print("titanic data")
print(df.head())
print("\n")
print("titanic data type")
print(type(df))
print("\n")

#데이터 프레임에 덧셈 연산
add_res = df + 10
print("titanic data add int 10")
print(add_res.head())
print("\n")

#덧셈한 데이터프레임에 원본 데이터 뺄셈
sub_res = add_res - df
print("titanic add_res sud org data")
print(sub_res.head())
print("\n")
# Out:
# titanic data
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500
#
#
# titanic data type
# <class 'pandas.core.frame.DataFrame'>
#
#
# titanic data add int 10
#     age     fare
# 0  32.0  17.2500
# 1  48.0  81.2833
# 2  36.0  17.9250
# 3  45.0  63.1000
# 4  45.0  18.0500
#
#
# titanic add_res sud org data
#     age  fare
# 0  10.0  10.0
# 1  10.0  10.0
# 2  10.0  10.0
# 3  10.0  10.0
# 4  10.0  10.0

# %%
#외부파일 읽어오기
#csv파일
#데이터 값을 쉽표로 구분 하고 있다는 의미

#옵션 매개변수명은 다음과 같다.
# path(기본) = 파일의 위치
# sep (또는 delimiter) = 텍스트 데이터를 필드별로 구분하는 문자
# header = 열 이릅으로 사용될 행의 번호(기본값은 0), 만약 헤더가 없는경우 None으로 지정해 주면 된다.
# index_col = 행 인덱스로 사용할 열의 번호 또는 이름
# names = 열 이름올 사용할 문자열의 리스트
# skiprows  = 처음 몇줄을 skip 할 것인지 여부 설정 (숫자 only), 다중 설정 시 리스트 형태로 지정 가능하다
# parse_datas = 날짜 텍스트를 datatime64로 변환 할것인지 설정, 기본은 False
# skip_footer = 마지막 볓줄을 skip할것인지 여부 설정 (숫자 only)
# encoding = 텍스트 인코딩 종류를 지정 (ex "utf-8")

#pandas모듈.read_csv(path(기본)="파일경로",옵션1, 옵션2, ... )

#판다스 모듈 추가
import pandas as pd

#파일 경로(파이썬 파일이 있는 폴더 기준으로 작성)를 찾고 변수에 저장
file_path = "./data/read_csv_sample.csv"

#read_csv()함수로 csv 데이터를 데이터프레임 타입으로 변환하여 적재
df = pd.read_csv(file_path)
print("read_csv(), 파일경로만 선택")
print(df)
print("\n")

#read_csv()함수로 csv 데이터를 데이터프레임 타입으로 변환, header=None 옵션 적용
df = pd.read_csv(file_path,header=None)
print("read_csv(), header=None 선택")
print(df)
print("\n")

#read_csv()함수로 csv 데이터를 데이터프레임 타입으로 변환, index_col=None 옵션 적용
df = pd.read_csv(file_path,index_col=None)
print("read_csv(), header=None 선택")
print(df)
print("\n")

#read_csv()함수로 csv 데이터를 데이터프레임 타입으로 변환, index_col=열 이름 옵션 적용
df = pd.read_csv(file_path,index_col='c0')
print("read_csv(), header=\'c0\' 선택")
print(df)
print("\n")
# Out:
# read_csv(), 파일경로만 선택
#    c0  c1  c2  c3
# 0   0   1   4   7
# 1   1   2   5   8
# 2   2   3   6   9
#
#
# read_csv(), header=None 선택
#     0   1   2   3
# 0  c0  c1  c2  c3
# 1   0   1   4   7
# 2   1   2   5   8
# 3   2   3   6   9
#
#
# read_csv(), header=None 선택
#    c0  c1  c2  c3
# 0   0   1   4   7
# 1   1   2   5   8
# 2   2   3   6   9
#
#
# read_csv(), header='c0' 선택
#     c1  c2  c3
# c0
# 0    1   4   7
# 1    2   5   8
# 2    3   6   9

# %%
#엑셀 파일
#excel파일 (확장자:xlsx)의 행과 열은 데이터프레임의 행,열과 1대1 대응된다.
#read_excel()함수의 사용법은 csv와 매우 유사하다. 옵션도 마찬가지,

#엑셀파일 -> 데이터프레임
#데이러프레임 객체 = 판다스모듈.read_excel(path="파일경로",engine = "openpyxl" ,옵션2, ...)

#실행 환경에 따라 engine 에 적용할 라이브러리 설치가 필요 할 수도 있으니 유의
# xlsx = openpyxl
# xls = xlrd

#판다스 모듈 추가
import pandas as pd

#read_excel() 함수호 데이터프레임 변환
df_1 = pd.read_excel( "./data/남북한발전전력량.xlsx" , engine = "openpyxl")
df_2 = pd.read_excel( "./data/남북한발전전력량.xlsx" , engine = "openpyxl", header=None)

#데이터프레임 출력
print(df_1)
print("\n")
print(df_2)
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  2007  \
# 0        남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...  4031
# 1       NaN     수력    64    51    49    60    41    55    52    54  ...    50
# 2       NaN     화력   484   573   696   803  1022  1122  1264  1420  ...  2551
# 3       NaN    원자력   529   563   565   581   587   670   739   771  ...  1429
# 4       NaN    신재생     -     -     -     -     -     -     -     -  ...     -
# 5        북한     합계   277   263   247   221   231   230   213   193  ...   236
# 6       NaN     수력   156   150   142   133   138   142   125   107  ...   133
# 7       NaN     화력   121   113   105    88    93    88    88    86  ...   103
# 8       NaN    원자력     -     -     -     -     -     -     -     -  ...     -
#
#    2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  4224  4336  4747  4969  5096  5171  5220  5281  5404
# 1    56    56    65    78    77    84    78    58    66
# ...

# %%
#json 파일
# json 파일은 데이터 공유를 목적으로 개발된 특수한 파일 형식이다.
#파이썬 딕셔너리와 비슷하게 키:값 구조로 되어 있는데, 구조가 중첩되는 방식에 따라 다르게 적용된다.

#json 파일 -> 데이터 프레임
#판다스모듈.read_json(파일경로)

#판다스 모듈 추가
import pandas as pd

#read_json() 메소드 함수 사용하여 json데이터를 데이터프레임으로 변환
df = pd.read_json("./data/read_json_sample.json")

print(df)
print("\n")
print(df.index)
# Out:
#            name  year        developer opensource
# pandas           2008    Wes Mckinneye       True
# NumPy            2006  Travis Oliphant       True
# matplotlib       2003   John D. Hunter       True
#
#
# Index(['pandas', 'NumPy', 'matplotlib'], dtype='object')

# %%
#HTML 웹 페이지에서 표 속성 가져오기
#판다스의 read_html()함수는 웹 페이지에 있는 <table>의 태그에서 표 형식의 데이터를 모두 찾아서 데이터 프레임으로 변환 한다.
# 표 데이터들은 각각 별도의 데이터프레임으로 변환되기 때문에 여러개의 데이터프레임으로 원소로 갖는 리스트가 반환된다.

#HTML 속성 표 읽기
#판다스모듈.read_html(웹주소 또는 html파일 로컬주소)

#판다스 모듈 추가
import pandas as pd

#HTML 파일의 경로 또는 웹페이지
url = "./data/sample.html"
tables = pd.read_html(url)

#표(table) 개수 확인
print(len(tables))

#table 리스트의 원소를 iteration 하면서 각가 화면에 출력
for count in range(len(tables)):
    print("tables[%s]" % count)
    print(tables[count])
    print("\n")

#파이썬 패키지 정보가 들어있는 두번째 데이터프레임을 선택하여 df변수에 저장
df = tables[1]

#name 열을 인덱스로 지정
df.set_index(["name"], inplace=True)
print(df)
# Out:
# 2
# tables[0]
#    Unnamed: 0  c0  c1  c2  c3
# 0           0   0   1   4   7
# 1           1   1   2   5   8
# 2           2   2   3   6   9
#
#
# tables[1]
#          name  year        developer  opensource
# 0       NumPy  2006  Travis Oliphant        True
# 1  matplotlib  2003   John D. Hunter        True
# 2      pandas  2008    Wes Mckinneye        True
#
#
#             year        developer  opensource
# name
# NumPy       2006  Travis Oliphant        True
# matplotlib  2003   John D. Hunter        True
# pandas      2008    Wes Mckinneye        True

# %%
#웹 스크래핑
#BeautifylSoup들 웹 스크래핑 도구로 수집한 데이터를 판다스 데이터프레임 형식으로 정리하는 과정
#웹에서 크롤링->파이썬의 리스트나 딕셔너리->데이터프레임변환

#각종 모듈과 라이브러리 호출
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

#위키피디아 마국 ETF웹 페이지에서 필요한 정보를 크롤링
#딕셔너리 형태로 변수 etfs에 저장
url = "https://en.wikipedia.org/wiki/List_of_American_exchange-traded_funds"
resp = requests.get(url)
soup = BeautifulSoup(resp.text, "lxml")
rows = soup.select("div > ul > li")

etfs = {}

for row in rows:
    try:
        efs_name = re.findall("^(.*) \(NYSE",row.text)
        efs_market = re.findall("\((.*)\|",row.text)
        efs_ticker = re.findall("NYSE Arca\|(.*)\)",row.text)
        
        if (len(efs_ticker) > 0 ) & (len(efs_market) > 0 ) & (len(efs_name) > 0 ):
            etfs[efs_ticker[0]] = [efs_market[0],efs_name[0]]
    
    except AttributeError as err:
        pass

#etfs 딕셔너리 출력
print(etfs)
print("\n")

#etfs 딕셔너리를 데이터프레임으로 변환
df = pd.DataFrame(etfs)
print(df)
# Out:
# {'DIA': ['NYSE Arca', 'DIAMONDS Trust, Series 1'], 'RSP': ['NYSE Arca', 'Guggenheim S&P 500 Equal Weight'], 'IOO': ['NYSE Arca', 'iShares S&P Global 100 Index'], 'IVV': ['NYSE Arca', 'iShares S&P 500 Index'], 'SPY': ['NYSE Arca', 'SPDR S&P 500'], 'VOO': ['NYSE Arca', 'Vanguard S&P 500'], 'IWM': ['NYSE Arca', 'iShares Russell 2000 Index'], 'OEF': ['NYSE Arca', 'iShares S&P 100 Index'], 'CVY': ['NYSE Arca', 'Guggenheim Multi-Asset Income'], 'RPG': ['NYSE Arca', 'Guggenheim S&P 500 Pure Growth ETF'], 'RPV': ['NYSE Arca', 'Guggenheim S&P 500 Pure Value ETF'], 'IWB': ['NYSE Arca', 'iShares Russell 1000 Index'], 'PKW': ['NYSE Arca', 'PowerShares Buyback Achievers'], 'PRF': ['NYSE Arca', 'PowerShares FTSE RAFI US 1000'], 'SPLV': ['NYSE Arca', 'PowerShares S&P 500 Low Volatility'], 'SCHX': ['NYSE Arca', 'Schwab US Large-Cap ETF'], 'SCHD': ['NYSE Arca', 'Schwab US Dividend Equity ETF'], 'FNDX': ['NYSE Arca', 'Schwab Fundamental U.S. Large Company Index ETF'], 'SDY': ['NYSE Arca', 'SPDR S&P Di
# ...

# %%
#데이터베이스로부터 판다스 데이터프레임 읽기 메소드
#read_sql()

# %%
#csv 파일로 저장
#데이터프레임객체.to_csv(파일명)
import pandas as pd
data = {
    "name":["jerry","Riah","Paul"],
    "algol":["A","A+","B"],
    "basic":["C","B","B+"],
    "c++":["B+","C","C+"]
}
df = pd.DataFrame(data)
df.set_index("name",inplace=True)
df.to_csv("./df_sample.csv")
# Out:
#       algol basic c++
# name
# jerry     A     C  B+
# Riah     A+     B   C
# Paul      B    B+  C+

# %%
#json파일로 저장
#데이터프레임객체.to_json(파일명)
import pandas as pd
data = {
    "name":["jerry","Riah","Paul"],
    "algol":["A","A+","B"],
    "basic":["C","B","B+"],
    "c++":["B+","C","C+"]
}
df = pd.DataFrame(data)
df.set_index("name",inplace=True)
df.to_json("./df_sample.json")

# %%
#엑셀파일로 저장
#데이터프레임객체.to_excel(파일명)
import pandas as pd
data = {
    "name":["jerry","Riah","Paul"],
    "algol":["A","A+","B"],
    "basic":["C","B","B+"],
    "c++":["B+","C","C+"]
}
df = pd.DataFrame(data)
df.set_index("name",inplace=True)
df.to_excel("./df_sample.xlsx")

# %%
#여러개의 데이터 프레임을 하나의 Excel로 저장
import pandas as pd

data_1 = {
    "name":["jerry","Riah","Paul"],
    "algol":["A","A+","B"],
    "basic":["C","B","B+"],
    "c++":["B+","C","C+"]
}
df_1 = pd.DataFrame(data_1)
df_1.set_index("name",inplace=True)

data_2 = {
    "c0":[1,2,3],
    "c1":[4,5,6],
    "c2":[7,8,9],
    "c3":[10,11,12],
    "c4":[13,14,15],
}
df_2 = pd.DataFrame(data_2)
df_2.set_index("c0",inplace=True)

#엑셀 워크북 객체 생성
write_data = pd.ExcelWriter("./df_sample_multi_dataframe.xlsx")

df_1.to_excel(write_data, sheet_name="df_1")
df_2.to_excel(write_data, sheet_name="df_2")

#워크북 객체 저장
write_data.save()

# %%
#데이터내용 미리보기
#기본 옵션은 5

#앞부분 미리보기
#데이터프레임객체.head(n)

#뒷부분 미리보기
#데이터프레임객체.tail(n)

import pandas as pd

#read_csv()메소드 사용하여 데이터프레임에 저장
df = pd.read_csv("./data/auto-mpg.csv",header=None)

#열 이름 지정
df.columns = [
    "mpg",
    "cylinders",
    "displacement",
    "horsepower",
    "weight",
    "acceleration",
    "model_year",
    "origin",
    "name"
]

print(df.head())
print("\n")
print(df.tail())
print("\n")
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino
#
#
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 393  27.0          4         140.0      86.00  2790.0          15.6
# 394  44.0          4          97.0      52.00  2130.0          24.6
# ...

# %%
#데이터 요약정보 확인하기

#데이터프레임의 크기(행의 개수, 열의 개수) 확인할때 사용한다.
#데이터프레임객체.shape

import pandas as pd

#read_csv()메소드 사용하여 데이터프레임에 저장
df = pd.read_csv("./data/auto-mpg.csv",header=None)

#열 이름 지정
df.columns = [
    "mpg",
    "cylinders",
    "displacement",
    "horsepower",
    "weight",
    "acceleration",
    "model_year",
    "origin",
    "name"
]

print(df.shape)
print("\n")
# Out:
# (398, 9)

# %%
#데이터프레임의 기본 정보출력
#클래스 유형, 행인덱스 구성, 열 이름의 종류와 개수, 각 열의 자료형과 개수, 
#메모리 할당량에 관한 정보 등등 관련 정보가 포함
#데이터프레임객체.info()

import pandas as pd

#read_csv()메소드 사용하여 데이터프레임에 저장
df = pd.read_csv("./data/auto-mpg.csv",header=None)

#열 이름 지정
df.columns = [
    "mpg",
    "cylinders",
    "displacement",
    "horsepower",
    "weight",
    "acceleration",
    "model_year",
    "origin",
    "name"
]

print(df.info())
print("\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    float64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB
# None

# %%
#판다스 자료형
#판다스는 Numpy를 기반으로 만들어 졌기 때문에 Numpy에서 사용하는 자료형을 기본적으로 사용 가능.
#데이터프레임 객체 클래스의 dtypes 속성을 활용하여 각 열의 자료형을 확인 할 수 있다.

import pandas as pd

#read_csv()메소드 사용하여 데이터프레임에 저장
df = pd.read_csv("./data/auto-mpg.csv",header=None)

#열 이름 지정
df.columns = [
    "mpg",
    "cylinders",
    "displacement",
    "horsepower",
    "weight",
    "acceleration",
    "model_year",
    "origin",
    "name"
]

#데이터프레임의 자료형 확인
print(df.dtypes)
print("\n")

#시리즈의 자료형 확인
print(df.mpg.dtypes)
print("\n")
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight          float64
# acceleration    float64
# model_year        int64
# origin            int64
# name             object
# dtype: object
#
#
# float64

# %%
#데이터프레임의 기술 통계정보 요약
#데이터프레임에 describe()메소드를 이용하면 산술데이터를 갖는 열에 대한 주요 기술 통계 정보(평균, 표준편차, 중간값 등)
#요약하여 보여준다

#데이터 프레임의 기술 통계 정보 요약
#데이터프레임객체.describe()

#산술 데이터가 아닌 열에 대한 정보를 포함하고 싶다면 옵션으로 include="all"을 넣어주면 된다.

import pandas as pd

#read_csv()메소드 사용하여 데이터프레임에 저장
df = pd.read_csv("./data/auto-mpg.csv",header=None)

#열 이름 지정
df.columns = [
    "mpg",
    "cylinders",
    "displacement",
    "horsepower",
    "weight",
    "acceleration",
    "model_year",
    "origin",
    "name"
]

print(df.describe())
print("\n")

print(df.describe(include="all"))
print("\n")
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model_year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000
#
#
# ...

# %%
#각 열의 데이터 개수
#데이터프레임객체.count()

#각 열의 고유값 개수
#데이터프레임객체.value_counts()

import pandas as pd

#read_csv()메소드 사용하여 데이터프레임에 저장
df = pd.read_csv("./data/auto-mpg.csv",header=None)

#열 이름 지정
df.columns = [
    "mpg",
    "cylinders",
    "displacement",
    "horsepower",
    "weight",
    "acceleration",
    "model_year",
    "origin",
    "name"
]

#각 열이 가지고 있는 원소 개수 확인
print(df.count())
print("\n")

#df.count()가 반환하는 객체 타입 출력
print(type(df.count()))
print("\n")

#데이터프레임의 특정 열이 가지고 있는 고유값 확인
unique_values = df["origin"].value_counts()
print(unique_values)
print("\n")

#value_counts()가 반환하는 값의 타입
print(type(unique_values))
print("\n")
# Out:
# mpg             398
# cylinders       398
# displacement    398
# horsepower      398
# weight          398
# acceleration    398
# model_year      398
# origin          398
# name            398
# dtype: int64
#
#
# <class 'pandas.core.series.Series'>
#
#
# 1    249
# 3     79
# 2     70
# Name: origin, dtype: int64
#
#
# <class 'pandas.core.series.Series'>

# %%
#통계함수 적용하기

#평균값
#중간값
#최대값
#최소값
#표준편차
#상관계수

import pandas as pd

#read_csv()메소드 사용하여 데이터프레임에 저장
df = pd.read_csv("./data/auto-mpg.csv",header=None)

#열 이름 지정
df.columns = [
    "mpg",
    "cylinders",
    "displacement",
    "horsepower",
    "weight",
    "acceleration",
    "model_year",
    "origin",
    "name"
]

#평균값
print("------------------평균값------------------")
print(df.mean())
print("\n")
print(df["mpg"].mean())
print(df.mpg.mean())
print("\n")
print(df[["mpg","weight"]].mean())
print("\n")

#중간값
print("------------------중간값------------------")
print(df.median())
print("\n")
print(df["mpg"].median())
print("\n")

#최대값
print("------------------최대값------------------")
print(df.max())
print("\n")
print(df["mpg"].max())
print("\n")
#최소값
print("------------------최소값------------------")
print(df.min())
print("\n")
print(df["mpg"].min())
print("\n")

#표준편차
print("------------------표준편차------------------")
print(df.std())
print("\n")
print(df["mpg"].std())
print("\n")

#상관계수
print("------------------상관계수------------------")
print(df.corr())
print("\n")
print(df[["mpg","weight"]].corr())
print("\n")
# Out:
# ------------------평균값------------------
# mpg               23.514573
# cylinders          5.454774
# displacement     193.425879
# weight          2970.424623
# acceleration      15.568090
# model_year        76.010050
# origin             1.572864
# dtype: float64
#
#
# 23.514572864321615
# 23.514572864321615
#
#
# mpg         23.514573
# weight    2970.424623
# dtype: float64
#
#
# ------------------중간값------------------
# mpg               23.0
# cylinders          4.0
# displacement     148.5
# weight          2803.5
# acceleration      15.5
# model_year        76.0
# origin             1.0
# dtype: float64
#
#
# 23.0
#
#
# ------------------최대값------------------
# mpg                         46.6
# cylinders                      8
# displacement               455.0
# horsepower                     ?
# weight                    5140.0
# acceleration                24.8
# model_year                    82
# origin                         3
# name            vw rabbit custom
# ...

# %%
#판다스 내장 그래프 도구 활용
#데이터를 그래프로 활용하는 것은 매우 효과적인 전달 방식이다.
#Matplotlib의 일부 기능을 내장하여 별도로 import하지 않아도 간단한 그래프를 사용 할 수 있다.
#plot() 매소드 옵션 -> kind="그래프명"

#kid 옵션

#line : 선
#bar : 수직막대 그래프
#barh : 수평막대 그래프
#hist : 히스토그램
#box : 박스 플롯
#kde : 커널 밀도 그래프
#area : 면적 그래프
#pie : 파이그래프
#scatter : 산점도 그래프
#hexbin : 고밀도 산점도 그래프

# %%
import pandas as pd

#데이터프레임 변환
df = pd.read_excel("./data/남북한발전전력량.xlsx", engine="openpyxl")

df_ns = df.iloc[[0,5],3:]
df_ns.index = ["South","North"]
df_ns.columns = df_ns.columns.map(int)
print(df_ns.head())
print("\n")

#선 그래프 그리기
df_ns.plot(kind="line")

#시간에 따른 연도별 발전량을 보기 위해서는 연도가 x축 (index)에 배치하는게 적절하다.
#행열 전치
tdf_ns = df_ns.T

print(tdf_ns.head())
print("\n")

#선그래프
#데이터프레임객체.plot(kind="line")
tdf_ns.plot(kind="line")

#막대 그래프
#데이터프레임객체.plot(kind="bar")
tdf_ns.plot(kind="bar")

#히스토그램
#데이터프레임객체.plot(kind="hist")
tdf_ns.plot(kind="hist")
# Out:
#        1991  1992  1993  1994  1995  1996  1997  1998  1999  2000  ...  2007  \
# South  1186  1310  1444  1650  1847  2055  2244  2153  2393  2664  ...  4031
# North   263   247   221   231   230   213   193   170   186   194  ...   236
#
#        2008  2009  2010  2011  2012  2013  2014  2015  2016
# South  4224  4336  4747  4969  5096  5171  5220  5281  5404
# North   255   235   237   211   215   221   216   190   239
#
# [2 rows x 26 columns]
#
#
#      South North
# 1991  1186   263
# 1992  1310   247
# 1993  1444   221
# 1994  1650   231
# 1995  1847   230
# <AxesSubplot:ylabel='Frequency'>

# %%
import pandas as pd

df = pd.read_csv("./data/auto-mpg.csv", header=None)

#열 이름 지정
df.columns = [
    "mpg",
    "cylinders",
    "displacement",
    "horsepower",
    "weight",
    "acceleration",
    "model_year",
    "origin",
    "name"
]

#산점도
#데이터프레임객체.plot(x="x축에 넣을 열 이름", y="y축에 넣을 열 이름", kind="scatter")
#2개 열을 사용하여 산점도 그리기
df.plot(x="weight",y="mpg",kind="scatter")

#박스 플롯
#데이터프레임객체[[열이름1, 열이름2]].plot(kind="box")
df[["mpg","cylinders"]].plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
#Matplotlib
#기본 그래프 도구

#데이터 분석에서 다루는 데이터의 종류는 매우 다양하며 크기도 수천 수만이 넘기는 경우도 흔하여 시각화 도구를 이용하는게 효과적이다.
#Matplotlib는 파이썬 표준 시각화 도구라고 부를 수 있을 정도로 2D 평면 그래프에 관하여 다양한 포맷과 기능을 지원한다.

# %%
#Matplotlib 에서 지원하는 스타일 종류
import matplotlib.pyplot as plt
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
#선 그래프 기본 사용법
import pandas as pd
import matplotlib.pyplot as plt

#한글 폰트 깨짐 현상 해결
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc("font",family=font_name)

#엑셀 파일을 데이터프레임객체로 변환
df = pd.read_excel("./data/시도별 전출입 인구수.xlsx",engine="openpyxl", header=0)

#누락값 (NaN)을 앞 데이터로 채우기 (엑셀로 따지면 병합)
df = df.fillna(method="ffill")

#서울에서 다른 지역으로 이동한 데이터만 추출
mask = (df["전출지별"]=="서울특별시") & (df["전입지별"] != "서울특별시")
df_seoul = df[mask]
df_seoul = df_seoul.drop("전출지별",axis=1)
df_seoul.rename(
    {"전입지별":"전입지"},
    axis = 1,
    inplace=True
)
df_seoul.set_index("전입지",inplace=True)

#서울에서 경기도로 이동한 인구 데이터 값만 선택
sr_one = df_seoul.loc["경기도"]

#스타일 서식 지정
plt.style.use("ggplot")

#그래프 사이즈 조정. figsize=(x,y) (단위는 inch)
plt.figure(figsize=(14,5))

#x측 눈금 라벨 회전
plt.xticks(rotation="vertical")

#선 그래프를 그리는 plot()함수에 x,y축 데이터를 선택한다.
#시리즈의 인덱스를 x축으로, 데이터값을 y축으로
plt.plot(
    sr_one.index, 
    sr_one.values,
    marker="X",     # Marker 사용
    markersize = 10 # Marker 크기
)

#시리즈데이터 자체를 plot()함수에 직접 입력도 가능하다.
plt.plot(sr_one)

#차트 그래프에 차트제목과 축 이름을 추가 할 수 있다
sr_one = df_seoul.loc["경기도"]

#x,y축 데이터를 plot함수에 입력
plt.plot(
    sr_one.index, 
    sr_one.values
)

#그래프 제목 추가
plt.title("서울->경기 인구 이동")

#축이름 추가
plt.xlabel("기간")
plt.ylabel("이동 인구수")

#범례표시
plt.legend(labels=["서울->경기"], loc="best")

#y축 데이터 범위 조정
plt.ylim(50000, 800000)

#그래프 부연 설명을 위한 주석 쓰기
#주석표시 - 화살표

plt.annotate(
    "",
    xy=(20,620000),    #화살표 머리 부분(종료점 >)
    xytext=(2,290000), #화살표 꼬리 부분(시작점 -)
    xycoords="data",   #좌표 기준 체계
    arrowprops=dict(   #화살표 서식
        arrowstyle="->",
        color="olive",
        lw=5
    )
)

plt.annotate(
    "",
    xy=(47,450000),    #화살표 머리 부분(종료점 >)
    xytext=(30,580000), #화살표 꼬리 부분(시작점 -)
    xycoords="data",   #좌표 기준 체계
    arrowprops=dict(   #화살표 서식
        arrowstyle="->",
        color="olive",
        lw=5
    )
)

#주석표시 - 텍스트
plt.annotate(
    "인구 이동 증가(70~95)",
    xy=(10,550000),
    rotation=25,
    va="baseline",
    ha="center",
    fontsize=15
)
plt.annotate(
    "인구 이동 감소(70~95)",
    xy=(40,560000),
    rotation=-11,
    va="baseline",
    ha="center",
    fontsize=15
)


#변경 사항 저장하고 출력
plt.show()

# %%
#화면 분할하여 그래프 그리기
import pandas as pd
import matplotlib.pyplot as plt

#한글 폰트 깨짐 현상 해결
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc("font",family=font_name)

#엑셀 파일을 데이터프레임객체로 변환
df = pd.read_excel("./data/시도별 전출입 인구수.xlsx",engine="openpyxl", header=0)

#누락값 (NaN)을 앞 데이터로 채우기 (엑셀로 따지면 병합)
df = df.fillna(method="ffill")

#서울에서 다른 지역으로 이동한 데이터만 추출
mask = (df["전출지별"]=="서울특별시") & (df["전입지별"] != "서울특별시")
df_seoul = df[mask]
df_seoul = df_seoul.drop("전출지별",axis=1)
df_seoul.rename(
    {"전입지별":"전입지"},
    axis = 1,
    inplace=True
)
df_seoul.set_index("전입지",inplace=True)

#서울에서 경기도로 이동한 인구 데이터 값만 선택
sr_one = df_seoul.loc["경기도"]

#스타일 서식 지정
plt.style.use("ggplot")

#그래프 객체생성
fig = plt.figure(figsize=(10,10))
#add_subplot(행,열,번호)
ax1 = fig.add_subplot(2,1,1)
ax2 = fig.add_subplot(2,1,2)

#axe객체에 plot함수로 그래프 출력
ax1.plot(sr_one,marker="o",markersize=10)
ax2.plot(sr_one,marker="o",markerfacecolor="green",markersize=10,color="olive",linewidth=2,label="서울->경기")
ax2.legend(loc="best")

#y축 범위 지정(최소, 최대)
ax1.set_ylim(50000,800000)
ax2.set_ylim(50000,800000)

#축 눈금라벨 지정 및 75도 회전
ax1.set_xticklabels(sr_one.index, rotation=75)
ax2.set_xticklabels(sr_one.index, rotation=75)

#변경 사항 저장하고 그래프 출력
plt.show()
# Out:
# <ipython-input-44-3b553ab678cc>:52: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(sr_one.index, rotation=75)
# <ipython-input-44-3b553ab678cc>:53: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(sr_one.index, rotation=75)

# %%
#선그래프 꾸미기 옵션
import pandas as pd
import matplotlib.pyplot as plt

#한글 폰트 깨짐 현상 해결
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc("font",family=font_name)

#엑셀 파일을 데이터프레임객체로 변환
df = pd.read_excel("./data/시도별 전출입 인구수.xlsx",engine="openpyxl", header=0)

#누락값 (NaN)을 앞 데이터로 채우기 (엑셀로 따지면 병합)
df = df.fillna(method="ffill")

#서울에서 다른 지역으로 이동한 데이터만 추출
mask = (df["전출지별"]=="서울특별시") & (df["전입지별"] != "서울특별시")
df_seoul = df[mask]
df_seoul = df_seoul.drop("전출지별",axis=1)
df_seoul.rename(
    {"전입지별":"전입지"},
    axis = 1,
    inplace=True
)
df_seoul.set_index("전입지",inplace=True)

#서울에서 경기도로 이동한 인구 데이터 값만 선택
sr_one = df_seoul.loc["경기도"]

#스타일 서식 지정
plt.style.use("ggplot")

#그래프 객체생성
fig = plt.figure(figsize=(20,5))
ax = fig.add_subplot(1,1,1)

#axe 객체에 plot함수로 그래프 출력
ax.plot(sr_one,marker="o",markerfacecolor="green",markersize=10,color="olive",linewidth=2,label="서울->경기")
ax.legend(loc="best")

#y축 범위 지정(최소, 최대)
ax.set_ylim(50000,800000)

#차트 제목 추가
ax.set_title("서울->경기 인구 이동",size=20)

#축 이름 추가
ax.set_ylabel("기간",size=12)
ax.set_xlabel("이동 인구수",size=12)

#축 눈금라벨 지정 및 75도 회전
ax.set_xticklabels(sr_one.index, rotation=75)

#축 눈금 라벨 크기
ax.tick_params(axis="x",labelsize=10)
ax.tick_params(axis="y",labelsize=10)

#변경사항 저장 및 출력
plt.show()
# Out:
# <ipython-input-46-9a495d3367e3>:53: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(sr_one.index, rotation=75)

# %%
#같은 화면에 그래프 추가
import pandas as pd
import matplotlib.pyplot as plt

#한글 폰트 깨짐 현상 해결
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc("font",family=font_name)

#엑셀 파일을 데이터프레임객체로 변환
df = pd.read_excel("./data/시도별 전출입 인구수.xlsx",engine="openpyxl", header=0)

#누락값 (NaN)을 앞 데이터로 채우기 (엑셀로 따지면 병합)
df = df.fillna(method="ffill")

#서울에서 다른 지역으로 이동한 데이터만 추출
mask = (df["전출지별"]=="서울특별시") & (df["전입지별"] != "서울특별시")
df_seoul = df[mask]
df_seoul = df_seoul.drop("전출지별",axis=1)
df_seoul.rename(
    {"전입지별":"전입지"},
    axis = 1,
    inplace=True
)
df_seoul.set_index("전입지",inplace=True)

#서울에서 충남,경북,강원으로 이동한 인구 데이터만 선택
col_years = list(map(str,range(1970,2018)))
df_3 = df_seoul.loc[["충청남도","경상북도","강원도"],col_years]

#스타일 서식 지정
plt.style.use("ggplot")

#그래프 객체생성
fig = plt.figure(figsize=(20,5))
ax = fig.add_subplot(1,1,1)

#axe 객체에 plot함수로 그래프 출력
ax.plot(col_years, df_3.loc["충청남도",:] ,marker="o",markerfacecolor="green",markersize=10,color="olive",linewidth=2,label="서울->충남")
ax.plot(col_years, df_3.loc["경상북도",:] ,marker="o",markerfacecolor="blue",markersize=10,color="skyblue",linewidth=2,label="서울->경북")
ax.plot(col_years, df_3.loc["강원도",:] ,marker="o",markerfacecolor="red",markersize=10,color="magenta",linewidth=2,label="서울->강원")

#범례표시
ax.legend(loc="best")

#차트 제목 추가
ax.set_title("서울->충남,경북,강원 인구 이동",size=20)

#축 이름 추가
ax.set_ylabel("기간",size=12)
ax.set_xlabel("이동 인구수",size=12)

#축 눈금라벨 지정 및 75도 회전
ax.set_xticklabels(sr_one.index, rotation=75)

#축 눈금 라벨 크기
ax.tick_params(axis="x",labelsize=10)
ax.tick_params(axis="y",labelsize=10)

#변경사항 저장 및 출력
plt.show()
# Out:
# <ipython-input-50-9f877623f980>:55: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(sr_one.index, rotation=75)

# %%
#Matplotlib에서 사용 가능한 색상
import matplotlib
colors={}
for name, hex in matplotlib.colors.cnames.items():
    colors[name] = hex
    
print(colors)
# Out:
# {'aliceblue': '#F0F8FF', 'antiquewhite': '#FAEBD7', 'aqua': '#00FFFF', 'aquamarine': '#7FFFD4', 'azure': '#F0FFFF', 'beige': '#F5F5DC', 'bisque': '#FFE4C4', 'black': '#000000', 'blanchedalmond': '#FFEBCD', 'blue': '#0000FF', 'blueviolet': '#8A2BE2', 'brown': '#A52A2A', 'burlywood': '#DEB887', 'cadetblue': '#5F9EA0', 'chartreuse': '#7FFF00', 'chocolate': '#D2691E', 'coral': '#FF7F50', 'cornflowerblue': '#6495ED', 'cornsilk': '#FFF8DC', 'crimson': '#DC143C', 'cyan': '#00FFFF', 'darkblue': '#00008B', 'darkcyan': '#008B8B', 'darkgoldenrod': '#B8860B', 'darkgray': '#A9A9A9', 'darkgreen': '#006400', 'darkgrey': '#A9A9A9', 'darkkhaki': '#BDB76B', 'darkmagenta': '#8B008B', 'darkolivegreen': '#556B2F', 'darkorange': '#FF8C00', 'darkorchid': '#9932CC', 'darkred': '#8B0000', 'darksalmon': '#E9967A', 'darkseagreen': '#8FBC8F', 'darkslateblue': '#483D8B', 'darkslategray': '#2F4F4F', 'darkslategrey': '#2F4F4F', 'darkturquoise': '#00CED1', 'darkviolet': '#9400D3', 'deeppink': '#FF1493', 'deepskyblu
# ...

# %%
#화면 4분할 그래프

import pandas as pd
import matplotlib.pyplot as plt

#한글 폰트 깨짐 현상 해결
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc("font",family=font_name)

#엑셀 파일을 데이터프레임객체로 변환
df = pd.read_excel("./data/시도별 전출입 인구수.xlsx",engine="openpyxl", header=0)

#누락값 (NaN)을 앞 데이터로 채우기 (엑셀로 따지면 병합)
df = df.fillna(method="ffill")

#서울에서 다른 지역으로 이동한 데이터만 추출
mask = (df["전출지별"]=="서울특별시") & (df["전입지별"] != "서울특별시")
df_seoul = df[mask]
df_seoul = df_seoul.drop("전출지별",axis=1)
df_seoul.rename(
    {"전입지별":"전입지"},
    axis = 1,
    inplace=True
)
df_seoul.set_index("전입지",inplace=True)

#서울에서 충남,경북,강원으로 이동한 인구 데이터만 선택
col_years = list(map(str,range(1970,2018)))
df_3 = df_seoul.loc[["충청남도","경상북도","강원도","전라남도"],col_years]

#스타일 서식 지정
plt.style.use("ggplot")

#그래프 객체생성
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

ax1.plot(col_years, df_3.loc["충청남도",:] ,marker="o",markerfacecolor="green",markersize=10,color="olive",linewidth=2,label="서울->충남")
ax2.plot(col_years, df_3.loc["경상북도",:] ,marker="o",markerfacecolor="blue",markersize=10,color="skyblue",linewidth=2,label="서울->경북")
ax3.plot(col_years, df_3.loc["강원도",:] ,marker="o",markerfacecolor="red",markersize=10,color="magenta",linewidth=2,label="서울->강원")
ax4.plot(col_years, df_3.loc["전라남도",:] ,marker="o",markerfacecolor="orange",markersize=10,color="yellow",linewidth=2,label="서울->전남")

#범례표시
ax1.legend(loc="best")
ax2.legend(loc="best")
ax3.legend(loc="best")
ax4.legend(loc="best")

#차트 제목 추가
ax1.set_title("서울->충남 인구 이동",size=20)
ax2.set_title("서울->경북 인구 이동",size=20)
ax3.set_title("서울->강원 인구 이동",size=20)
ax4.set_title("서울->전남 인구 이동",size=20)

#축 눈금라벨 지정 및 90도 회전
ax1.set_xticklabels(sr_one.index, rotation=90)
ax2.set_xticklabels(sr_one.index, rotation=90)
ax3.set_xticklabels(sr_one.index, rotation=90)
ax4.set_xticklabels(sr_one.index, rotation=90)

#변경사항 적용 및 출력
plt.show()
# Out:
# <ipython-input-52-70fe18aaa963>:61: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(sr_one.index, rotation=90)
# <ipython-input-52-70fe18aaa963>:62: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(sr_one.index, rotation=90)
# <ipython-input-52-70fe18aaa963>:63: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels(sr_one.index, rotation=90)
# <ipython-input-52-70fe18aaa963>:64: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax4.set_xticklabels(sr_one.index, rotation=90)

# %%
#면적 그래프

import pandas as pd
import matplotlib.pyplot as plt

#한글 폰트 깨짐 현상 해결
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc("font",family=font_name)

#엑셀 파일을 데이터프레임객체로 변환
df = pd.read_excel("./data/시도별 전출입 인구수.xlsx",engine="openpyxl", header=0)

#누락값 (NaN)을 앞 데이터로 채우기 (엑셀로 따지면 병합)
df = df.fillna(method="ffill")

#서울에서 다른 지역으로 이동한 데이터만 추출
mask = (df["전출지별"]=="서울특별시") & (df["전입지별"] != "서울특별시")
df_seoul = df[mask]
df_seoul = df_seoul.drop("전출지별",axis=1)
df_seoul.rename(
    {"전입지별":"전입지"},
    axis = 1,
    inplace=True
)
df_seoul.set_index("전입지",inplace=True)

#서울에서 충남,경북,강원으로 이동한 인구 데이터만 선택
col_years = list(map(str,range(1970,2018)))
df_4 = df_seoul.loc[["충청남도","경상북도","강원도","전라남도"],col_years]
df_4 = df_4.transpose()

#스타일 서식 지정
plt.style.use("ggplot")

#데이터프레임의 인덱스를 정수형으로 변경
df_4.index = df_4.index.map(int)

#면적 그래프 그리기
#면적 그래프 옵션인 stacked가 기본옵션인 false면 서로 겹처서 나옴
# stacked가 True면 겹치지 않고 위아래로 누적 되면서 출력 
df_4.plot(kind="area", stacked=False, alpha=0.2, figsize=(20,10))

plt.title("서울->타시도 인구 이동",size=30)
plt.ylabel("기간",size=12)
plt.xlabel("이동 인구수",size=12)
plt.legend(loc="best",fontsize=15)

#변경사항 적용 & 출력
plt.show()

# %%
#axe객체 속성 변경

import pandas as pd
import matplotlib.pyplot as plt

#한글 폰트 깨짐 현상 해결
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc("font",family=font_name)

#엑셀 파일을 데이터프레임객체로 변환
df = pd.read_excel("./data/시도별 전출입 인구수.xlsx",engine="openpyxl", header=0)

#누락값 (NaN)을 앞 데이터로 채우기 (엑셀로 따지면 병합)
df = df.fillna(method="ffill")

#서울에서 다른 지역으로 이동한 데이터만 추출
mask = (df["전출지별"]=="서울특별시") & (df["전입지별"] != "서울특별시")
df_seoul = df[mask]
df_seoul = df_seoul.drop("전출지별",axis=1)
df_seoul.rename(
    {"전입지별":"전입지"},
    axis = 1,
    inplace=True
)
df_seoul.set_index("전입지",inplace=True)

#서울에서 충남,경북,강원으로 이동한 인구 데이터만 선택
col_years = list(map(str,range(1970,2018)))
df_4 = df_seoul.loc[["충청남도","경상북도","강원도","전라남도"],col_years]
df_4 = df_4.transpose()

#스타일 서식 지정
plt.style.use("ggplot")

#데이터프레임의 인덱스를 정수형으로 변경
df_4.index = df_4.index.map(int)

#AXE 객체 생성
ax = df_4.plot(kind="area", stacked=True, alpha=0.2, figsize=(20,10))

ax.set_title("서울->타시도 인구 이동",size=30, color="brown", weight="bold")
ax.set_ylabel("기간",size=12, color="blue")
ax.set_xlabel("이동 인구수",size=12, color="blue")
ax.legend(loc="best",fontsize=15)

#변경사항 적용 & 출력
plt.show()

# %%
#막대그래프
#막대그래프는 데이터 값의 크기에 비례하여 높이를 갖는 직사각형 막대로 표현한다.
import pandas as pd
import matplotlib.pyplot as plt

#한글 폰트 깨짐 현상 해결
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc("font",family=font_name)

#엑셀 파일을 데이터프레임객체로 변환
df = pd.read_excel("./data/시도별 전출입 인구수.xlsx",engine="openpyxl", header=0)

#누락값 (NaN)을 앞 데이터로 채우기 (엑셀로 따지면 병합)
df = df.fillna(method="ffill")

#서울에서 다른 지역으로 이동한 데이터만 추출
mask = (df["전출지별"]=="서울특별시") & (df["전입지별"] != "서울특별시")
df_seoul = df[mask]
df_seoul = df_seoul.drop("전출지별",axis=1)
df_seoul.rename(
    {"전입지별":"전입지"},
    axis = 1,
    inplace=True
)
df_seoul.set_index("전입지",inplace=True)

#서울에서 충남,경북,강원으로 이동한 인구 데이터만 선택
col_years = list(map(str,range(2010,2018)))
df_4 = df_seoul.loc[["충청남도","경상북도","강원도","전라남도"],col_years]
df_4 = df_4.transpose()

#스타일 서식 지정
plt.style.use("ggplot")

#데이터프레임의 인덱스를 정수형으로 변경
df_4.index = df_4.index.map(int)

df_4.plot(kind="bar", figsize=(20,10), width=0.7, color=["orange","green","red","blue"])

plt.title("서울->타시도 인구 이동",size=30)
plt.ylabel("기간",size=12)
plt.xlabel("이동 인구수",size=12)
plt.ylim(5000,30000)
plt.legend(loc="best",fontsize=15)

#변경사항 적용 & 출력
plt.show()

# %%
#가로형 막대그래프
#가로형 막대 그래프는 각 변수 값의 크기 차이를 설명할때 적합하다

import pandas as pd
import matplotlib.pyplot as plt

#한글 폰트 깨짐 현상 해결
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc("font",family=font_name)

#엑셀 파일을 데이터프레임객체로 변환
df = pd.read_excel("./data/시도별 전출입 인구수.xlsx",engine="openpyxl", header=0)

#누락값 (NaN)을 앞 데이터로 채우기 (엑셀로 따지면 병합)
df = df.fillna(method="ffill")

#서울에서 다른 지역으로 이동한 데이터만 추출
mask = (df["전출지별"]=="서울특별시") & (df["전입지별"] != "서울특별시")
df_seoul = df[mask]
df_seoul = df_seoul.drop("전출지별",axis=1)
df_seoul.rename(
    {"전입지별":"전입지"},
    axis = 1,
    inplace=True
)
df_seoul.set_index("전입지",inplace=True)

#서울에서 충남,경북,강원으로 이동한 인구 데이터만 선택
col_years = list(map(str,range(2010,2018)))
df_4 = df_seoul.loc[["충청남도","경상북도","강원도","전라남도"],col_years]

#10~17 이동 인구수를 합계하여 새로운 열로 추가
df_4["합계"]=df_4.sum(axis=1)

#가장 큰 값부터 정렬
df_total=df_4[["합계"]].sort_values(by="합계",ascending=True)

#스타일 서식 지정
plt.style.use("ggplot")

df_total.plot(kind="barh", figsize=(20,10), width=0.5, color="blue")

plt.title("서울->타시도 인구 이동",size=30)
plt.ylabel("기간",size=12)
plt.xlabel("이동 인구수",size=12)

#변경사항 적용 & 출력
plt.show()

# %%
#보조축 활용하기
import pandas as pd
import matplotlib.pyplot as plt

#한글 폰트 깨짐 현상 해결
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc("font",family=font_name)

#스타일 서식 지정
plt.style.use("ggplot")

#마이너스 부호 출력 설정
plt.rcParams["axes.unicode_minus"]=False

#데이터프레임 변환
df = pd.read_excel("./data/남북한발전전력량.xlsx", engine="openpyxl", convert_float=True)
df=df.loc[5:9]
df.drop("전력량 (억㎾h)",axis="columns",inplace=True)
df.set_index("발전 전력별",inplace=True)
df = df.T

#증감률 계산
df = df.rename(columns={"합계":"총발전량"})
df["총발전량-1년"] = df["총발전량"].shift(1)
df["증감률"] = ( ( df["총발전량"] / df["총발전량-1년"] ) - 1 )*100

#2축 그래프 그리기
ax1 = df[["수력","화력"]].plot(kind="bar", figsize=(20,20), width=0.7, stacked=True)
ax2 = ax1.twinx()
ax2.plot(df.index, df.증감률, ls="--", marker="o", markersize=20, color="red",label="전년 대비 증감률(%)")

ax1.set_ylim(0,500)
ax2.set_ylim(-50,50)

ax1.set_xlabel("연도",size=20)
ax1.set_ylabel("발전량 (억kWh)")
ax2.set_ylabel("전년 대비 증감률(%)")

plt.title("북한 전력 발전량 (1990~2016)",size=30)
plt.legend(loc="best")

plt.show()

# %%
#히스토그램

import pandas as pd
import matplotlib.pyplot as plt

plt.style.use("classic")

df=pd.read_csv("./data/auto-mpg.csv",header=None)

#열 이름 지정
df.columns = [
    "mpg",
    "cylinders",
    "displacement",
    "horsepower",
    "weight",
    "acceleration",
    "model_year",
    "origin",
    "name"
]

#연비 열에 대한 히스토그램 출력
df["mpg"].plot(kind="hist", bins=10, color="coral", figsize=(10,5))

#그래프 꾸미기
plt.title("Histogram")
plt.xlabel("mpg")
plt.show()

# %%
#산점도

import pandas as pd
import matplotlib.pyplot as plt

plt.style.use("classic")

df=pd.read_csv("./data/auto-mpg.csv",header=None)

#열 이름 지정
df.columns = [
    "mpg",
    "cylinders",
    "displacement",
    "horsepower",
    "weight",
    "acceleration",
    "model_year",
    "origin",
    "name"
]

#연비 열에 대한 산점도 출력
df.plot(kind="scatter", x="weight", y="mpg", c="coral", s=10, figsize=(10,5))

#그래프 꾸미기
plt.title("Scatter plot - mpg vs weigth")
plt.show()

# %%
#산점도-버블차트
#산점도의 점의 크기에 변화를 주어서 거품과 같이 생겼다고 지어진 이름

import pandas as pd
import matplotlib.pyplot as plt

plt.style.use("classic")

df=pd.read_csv("./data/auto-mpg.csv",header=None)

#열 이름 지정
df.columns = [
    "mpg",
    "cylinders",
    "displacement",
    "horsepower",
    "weight",
    "acceleration",
    "model_year",
    "origin",
    "name"
]

#실린더 개수의 상대적 비율을 계산하여 시리즈 생성
cylinders_size = df.cylinders / df.cylinders.max() * 300

#연비 열에 대한 산점도 출력
df.plot(kind="scatter", x="weight", y="mpg", c="coral", s=cylinders_size, alpha=0.3, figsize=(10,5))

#그래프 꾸미기
plt.title("Scatter plot - mpg vs weigth")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use("classic")

df=pd.read_csv("./data/auto-mpg.csv",header=None)

#열 이름 지정
df.columns = [
    "mpg",
    "cylinders",
    "displacement",
    "horsepower",
    "weight",
    "acceleration",
    "model_year",
    "origin",
    "name"
]

#실린더 개수의 상대적 비율을 계산하여 시리즈 생성
cylinders_size = df.cylinders / df.cylinders.max() * 300

#연비 열에 대한 산점도 출력, 컬러맵 옵션(cmap)="viridis" 적용, 컬러별로 색상 다양화
df.plot(kind="scatter", x="weight", y="mpg", marker="+", c=cylinders_size, s=50, alpha=0.3, cmap="viridis", figsize=(10,5))

#그래프 꾸미기
plt.title("Scatter plot - mpg vs weigth")

#그래프를 그림파일로 저장, 투명화 옵션 선택
plt.savefig("./save_image.png",transparent=True)

#변경사항 적용 후 출력
plt.show()

# %%
#파이차트

import pandas as pd
import matplotlib.pyplot as plt

plt.style.use("classic")

df=pd.read_csv("./data/auto-mpg.csv",header=None)

#열 이름 지정
df.columns = [
    "mpg",
    "cylinders",
    "displacement",
    "horsepower",
    "weight",
    "acceleration",
    "model_year",
    "origin",
    "name"
]

#데이터 개수 카운트 위해 값 1을 가진 열 추가
df["count"] = 1
df_origin = df.groupby("origin").sum()

#제조국가(origin) 값을 실제 지역명으로 변경
df_origin.index = ["USA","EU","JPN"]

#제조국가 열에 대한 파이차트 그리기
df_origin["count"].plot(
    kind="pie",
    figsize=(7,5),
    autopct="%1.1f%%",
    startangle=10,
    colors=["chocolate","bisque","cadetblue"]
)

plt.title("Model Origin",size=20)
plt.axis("equal")
plt.legend(labels=df_origin.index, loc="upper right")
plt.show()

# %%
#박스플롯

import pandas as pd
import matplotlib.pyplot as plt

plt.style.use("classic")

df=pd.read_csv("./data/auto-mpg.csv",header=None)

#열 이름 지정
df.columns = [
    "mpg",
    "cylinders",
    "displacement",
    "horsepower",
    "weight",
    "acceleration",
    "model_year",
    "origin",
    "name"
]

#그래프 객체 생성, 
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

#axe객체에 boxplot 메소드로 그래프 출력
ax1.boxplot(
    x=[
        df[df["origin"]==1]["mpg"],
        df[df["origin"]==2]["mpg"],
        df[df["origin"]==3]["mpg"]
    ],
    labels=["USA","EU","JPN"]
)

ax2.boxplot(
    x=[
        df[df["origin"]==1]["mpg"],
        df[df["origin"]==2]["mpg"],
        df[df["origin"]==3]["mpg"]
    ],
    labels=["USA","EU","JPN"],
    vert=False
)

ax1.set_title("Fuel economy distribution by made country(vertical boxplot)")
ax2.set_title("Fuel economy distribution by made country(horizontal boxplot)")

plt.show()

# %% [markdown]
# ===============================================================================================================
#
# 파이썬 그래프 갤러리
#
#     파이썬으로 그릴 수 있는 다양한 그래프 설정 관련 옵션 등등 참조 할만한 사이트
#     https://python-graph-gallery.com
#
# ===============================================================================================================

# %%
#데이터셋 가져오기
#seaborn은 matplotlib의 기능과 스타일을 확장한 파이썬 시각화 도구의 고급 버전이다.
#비교적 단순한 인터페이스를 제공하기 때문에 초보자도 어렵지 않게 배울 수 있다

import seaborn as sns

#titanic 데이터셋
titanic = sns.load_dataset("titanic")

#titanic 데이터셋 살펴보기
print(titanic.head())
print("\n")
print(titanic.info())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
# ...

# %%
#회귀선이 있는 산점도

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#titanic 데이터셋
titanic = sns.load_dataset("titanic")

#스타일테마 설정
#지원 가능한 스타일 : darkgrid, whitegrid, dark, white, ticks
sns.set_style("darkgrid")

#그래프 객체 생성
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

#그래프 그리기 선형회귀선 표시
sns.regplot(
    x="age",
    y="fare",
    data=titanic,
    ax=ax1
)

#그래프 그리기 선형회귀선 미표시
sns.regplot(
    x="age",
    y="fare",
    data=titanic,
    ax=ax2,
    fit_reg=False
)

plt.show()

# %%
#히스토그램/커널 밀도 그래프

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#titanic 데이터셋
titanic = sns.load_dataset("titanic")

#스타일테마 설정
#지원 가능한 스타일 : darkgrid, whitegrid, dark, white, ticks
sns.set_style("darkgrid")

#그래프 객체 생성
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,3,1)
ax2 = fig.add_subplot(1,3,2)
ax3 = fig.add_subplot(1,3,3)

#distplot
sns.distplot(titanic["fare"], ax=ax1)

#kdeplot
sns.kdeplot(x="fare", data=titanic, ax=ax2)

#histplot
sns.histplot(x="fare", data=titanic, ax=ax3)

#차트제목 표시
ax1.set_title("titanic fare - hist/ked")
ax2.set_title("titanic fare - ked")
ax3.set_title("titanic fare - hist")

plt.show()
# Out:
# C:\Users\ajg10\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#히트맵

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#titanic 데이터셋
titanic = sns.load_dataset("titanic")

#스타일테마 설정
#지원 가능한 스타일 : darkgrid, whitegrid, dark, white, ticks
sns.set_style("darkgrid")

table = titanic.pivot_table(index=["sex"], columns=["class"], aggfunc="size")

#히트맵 그리기
sns.heatmap(
    table,
    annot=True,
    fmt="d",
    cmap="YlGnBu",
    linewidth=5,
    cbar=False
)

plt.show()

# %%
#범주형 데이터의 선점도

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#titanic 데이터셋
titanic = sns.load_dataset("titanic")

#스타일테마 설정
#지원 가능한 스타일 : darkgrid, whitegrid, dark, white, ticks
sns.set_style("whitegrid")

#그래프 객체 생성
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

#이산형 변수의 분포 - 데이터 분산 미고려(중복 표시 O)
sns.stripplot(
    x="class",
    y="age",
    data=titanic,
    ax=ax1
)

#이산형 변수의 분포 - 데이터 분산 고려(중복 표시 X)
sns.swarmplot(
    x="class",
    y="age",
    data=titanic,
    ax=ax2
)

ax1.set_title("strip plot")
ax2.set_title("swarm plot")

plt.show()
# Out:
# C:\Users\ajg10\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 12.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
#막대 그래프

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#titanic 데이터셋
titanic = sns.load_dataset("titanic")

#스타일테마 설정
#지원 가능한 스타일 : darkgrid, whitegrid, dark, white, ticks
sns.set_style("whitegrid")

#그래프 객체 생성
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,3,1)
ax2 = fig.add_subplot(1,3,2)
ax3 = fig.add_subplot(1,3,3)

#X축,Y축에 대한 변수 할당
sns.barplot(x="sex", y="survived", data=titanic, ax=ax1)

#X축,Y축에 대한 변수 할당하고 hue 옵션
sns.barplot(x="sex", y="survived", hue="class",data=titanic, ax=ax2)

#X축,Y축에 대한 변수 할당하고 hue 옵션추가 하고 누적 출력
sns.barplot(x="sex", y="survived", hue="class", dodge=False, data=titanic, ax=ax3)

#차트제목 표시
ax1.set_title("titanic fare - sex")
ax2.set_title("titanic fare - sex/class")
ax3.set_title("titanic fare - sex/class(stacked)")

plt.show()

# %%
#빈도 그래프


import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#titanic 데이터셋
titanic = sns.load_dataset("titanic")

#스타일테마 설정
#지원 가능한 스타일 : darkgrid, whitegrid, dark, white, ticks
sns.set_style("whitegrid")

#그래프 객체 생성
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,3,1)
ax2 = fig.add_subplot(1,3,2)
ax3 = fig.add_subplot(1,3,3)

#기본값
sns.countplot(x="class",palette="Set1",data=titanic,ax=ax1)

#hue옵션에 who추가
sns.countplot(x="class",palette="Set2",data=titanic,hue="who",ax=ax2)

#dodge=False 옵션 추가
sns.countplot(x="class",palette="Set3",data=titanic,hue="who",dodge=False,ax=ax3)

#차트제목 표시
ax1.set_title("titanic class ")
ax2.set_title("titanic class - who")
ax3.set_title("titanic class - who(stacked)")

plt.show()

# %%
#박스플롯 / 바이올린 그래프

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#titanic 데이터셋
titanic = sns.load_dataset("titanic")

#스타일테마 설정
#지원 가능한 스타일 : darkgrid, whitegrid, dark, white, ticks
sns.set_style("whitegrid")

#그래프 객체 생성
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

#box plot
sns.boxplot(x="alive",y="age",data=titanic,ax=ax1)

#box plot + hue옵션
sns.boxplot(x="alive",y="age", hue="sex",data=titanic,ax=ax2)

#violin plot
sns.violinplot(x="alive",y="age",data=titanic,ax=ax3)

#violin plot + hue옵션
sns.violinplot(x="alive",y="age", hue="sex",data=titanic,ax=ax4)

plt.show()

# %%
#조인트 그래프

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#titanic 데이터셋
titanic = sns.load_dataset("titanic")

#스타일테마 설정
#지원 가능한 스타일 : darkgrid, whitegrid, dark, white, ticks
sns.set_style("whitegrid")

#조인트 그래프 - 산점도 기본
j1=sns.jointplot(x="fare",y="age",data=titanic)

#조인트 그래프 - 회귀선
j2=sns.jointplot(x="fare",y="age", kind="reg",data=titanic)

#조인트 그래프 - 육각그래프
j3=sns.jointplot(x="fare",y="age", kind="hex",data=titanic)

#조인트 그래프 - 커널 밀집 그래프
j4=sns.jointplot(x="fare",y="age", kind="kde",data=titanic)

#제목 등록
j1.fig.suptitle("scatter",size=15)
j2.fig.suptitle("reg",size=15)
j3.fig.suptitle("hex",size=15)
j4.fig.suptitle("kde",size=15)

plt.show()

# %%
#조건 적용하여 화면을 그리드로 분할

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#titanic 데이터셋
titanic = sns.load_dataset("titanic")

#스타일테마 설정
#지원 가능한 스타일 : darkgrid, whitegrid, dark, white, ticks
sns.set_style("whitegrid")

#조건에 따라 그래프 나누기
g = sns.FacetGrid(data=titanic, col="who", row="survived")

#그래프 적용
g = g.map(plt.hist, "age")

# %%
#이변수 데이터의 분포

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#titanic 데이터셋
titanic = sns.load_dataset("titanic")

#스타일테마 설정
#지원 가능한 스타일 : darkgrid, whitegrid, dark, white, ticks
sns.set_style("whitegrid")

#titanic데이터 세트 중에서 분석 데이터 선택하기
titanic_pair = titanic[["age","pclass","fare"]]

#조건에 따라 그래프 나누기
g = sns.pairplot(titanic_pair)

# %% [markdown]
# 지도 만들기 특집.
#
#     Folium 라이브러리 활용
#     Folium 라이브러리는 지도위에 데이터를 시각화 할때 유용하다.
#
#     아나콘다 설치 방법
#     conda install -c conda-forge folium

# %%
#지도 만들기

#모듈 등록
import folium

#서울지도 생성
seoul_map = folium.Map(location=[37.55,126.98],zoom_start=12)

#지도를 HTML file로 저장하기
seoul_map.save("./data/seoul_map.html")

# %%
#지도 스타일 적용하기

#모듈 등록
import folium

seoul_map_1 = folium.Map(location=[37.55,126.98], tiles="stamen Terrain",zoom_start=12)
seoul_map_2 = folium.Map(location=[37.55,126.98], tiles="stamen Toner",zoom_start=12)

#지도를 HTML file로 저장하기
seoul_map_1.save("./data/seoul_map_1.html")
seoul_map_2.save("./data/seoul_map_2.html")

# %%
#지도에 마커 표기

#모듈 등록
import folium
import pandas as pd

#서울지역 대학교 정보 불러오기
df = pd.read_excel("./data/서울지역 대학교 위치.xlsx",engine="openpyxl")

#서울지도 생성
seoul_map = folium.Map(location=[37.55,126.98], tiles="stamen Terrain",zoom_start=12)

#대학교 위치 마커로 표기
for name,lat,lng in zip(df.index, df.위도, df.경도):
    folium.Marker([lat,lng], popup=name).add_to(seoul_map)

#지도를 HTML file로 저장하기
seoul_map.save("./data/seoul_map_3.html")

# %%
#지도에 원형마커 표기

#모듈 등록
import folium
import pandas as pd

#서울지역 대학교 정보 불러오기
df = pd.read_excel("./data/서울지역 대학교 위치.xlsx",engine="openpyxl")

#서울지도 생성
seoul_map = folium.Map(location=[37.55,126.98], tiles="stamen Terrain",zoom_start=12)

#대학교 위치 마커로 표기
for name,lat,lng in zip(df.index, df.위도, df.경도):
    folium.Marker(
        [lat,lng],
        radius=10,
        color="brown",
        fill=True,
        fill_color="coral",
        fiil_opacity=0.7,
        popup=name
    ).add_to(seoul_map)

#지도를 HTML file로 저장하기
seoul_map.save("./data/seoul_map_4.html")

# %%
#지도 영역에 단계 구분도 표시

#모듈 등록
import folium
import pandas as pd
import json

file_path = "./data/경기도인구데이터.xlsx"
df = pd.read_excel(file_path, index_col="구분", engine="openpyxl")
df.columns = df.columns.map(str)

geo_path = "./data/경기도행정구역경계.json"
try:
    geo_data = json.load(open(geo_path,encoding="utf-8"))
except:
    geo_data = json.load(open(geo_path,encoding="utf-8-sig"))

#경기도 지도 만들기
g_map = folium.Map(location=[37.5502,126.982], tiles="stamen Terrain",zoom_start=9)
    
#출력할 연도 선택
year = "2007"

#choropleth 클래스로 단계구분 표시하기
folium.Choropleth(
    geo_data = geo_data,
    data = df[year],
    columns = [df.index , df[year]],
    fill_color="YlOrRd",fiil_opacity=0.7,line_opacity=0.3,
    threshold_scale=[10000,100000,300000,500000,700000],
    key_on="feature.properties.name"
).add_to(g_map)

#지도를 HTML파일로 저장하기
g_map.save("./data/gyonggi_poulation_"+year+".html")

# %%
#누락 데이터 확인
#타이타닉 데이터셑을 확인 해 보면 RangeIndex가 891개인 반면 deck에 203개의 유효한 데이터가 있다
#즉 누락 데이터가 (RangeIndex-deck유효데이터)의 개수가 존대한다.

import seaborn as sns

#titanic 데이터셋
df = sns.load_dataset("titanic")

#데이터 확인
print("----------------------------------------데이터 확인--------------------------------------------")
print(df.info())
print(df)

#누락 데이터 NaN개수 확인
nan_count_deck = df["deck"].value_counts(dropna=False)
print("----------------------------------------누락 데이터 NaN개수 확인--------------------------------------------")
print(nan_count_deck)

#메소드로 누락 데이터 확인하기

# isnull = 누락데이터가 존재하면 True 반환
print("----------------------------------------isnull()로 누락 데이터 확인--------------------------------------------")
print(df.head().isnull())

# notnull() = 누락데이터가 없으면 true 반환
print("----------------------------------------notnull()로 누락 데이터 확인--------------------------------------------")
print(df.head().notnull())

# isnull() 이용하여 누락데이터 개수 파악
print("----------------------------------------isnull()로 누락 데이터 개수 확인--------------------------------------------")
print(df.head().isnull().sum(axis=0))
# Out:
# ----------------------------------------데이터 확인--------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# ...

# %%
#누락 데이터 제거하기

import seaborn as sns

#titanic 데이터셋
df = sns.load_dataset("titanic")

#For 반복문으로 각 열의 NaN 데이터 제거하기
missing_df = df.isnull()
for column_count in df.isnull():
    #각 열의 NaN개수 파악
    missing_count=missing_df[column_count].value_counts()
    
    try:
        print(column_count, ":", missing_count[True])
    
    except:
        print(column_count, ":", 0)

#NaN 데이터가 500개 이상인 열 제거. 500은 변경 가능하다
df_thresh = df.dropna(axis=1,thresh=500)
print(df_thresh.columns)
# Out:
# survived : 0
# pclass : 0
# sex : 0
# age : 177
# sibsp : 0
# parch : 0
# fare : 0
# embarked : 2
# class : 0
# who : 0
# adult_male : 0
# deck : 688
# embark_town : 2
# alive : 0
# alone : 0
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %%
#평균 값으로 치환

import seaborn as sns

#titanic 데이터셋
df = sns.load_dataset("titanic")

#age 열의 첫 10개 데이터 출력
print(df["age"].head(10))
print("\n")

#age열의 NaN값 대신 다른 나이 데이터의 평균으로 치환하기
#age열의 평균 계산 (NaN 데이터 제외)
mean_age = df["age"].mean(axis=0)
df["age"].fillna(mean_age, inplace=True)

#age열의 첫 10개 데이터 출력 (5행에 NaN가 평균으로 대체)
print(df["age"].head(10))
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5     NaN
# 6    54.0
# 7     2.0
# 8    27.0
# 9    14.0
# Name: age, dtype: float64
#
#
# 0    22.000000
# 1    38.000000
# 2    26.000000
# 3    35.000000
# 4    35.000000
# 5    29.699118
# 6    54.000000
# 7     2.000000
# 8    27.000000
# 9    14.000000
# Name: age, dtype: float64

# %%
# 가장 많이 나오는 값으로 치환

import seaborn as sns

#titanic 데이터셋
df = sns.load_dataset("titanic")

#embark_town열의 829행의 NaN데이터 출력
print(df["embark_town"][825:830])
print("\n")

#embark_town열의 NaN값을 승선 도시 중에서 가장 많이 출현한 값으로 치환하기
most_freq = df["embark_town"].value_counts(dropna=True).idxmax()
print(most_freq)
print("\n")

df["embark_town"].fillna(most_freq, inplace=True)

#embark_town열 829행의 NaN데이터 출력
print(df["embark_town"][825:830])
# Out:
# 825     Queenstown
# 826    Southampton
# 827      Cherbourg
# 828     Queenstown
# 829            NaN
# Name: embark_town, dtype: object
#
#
# Southampton
#
#
# 825     Queenstown
# 826    Southampton
# 827      Cherbourg
# 828     Queenstown
# 829    Southampton
# Name: embark_town, dtype: object

# %%
#이웃하고 있는 값으로 치환
#fillna의 method 옵션에 ffill넣어 주면 이전 행의 데이터가, bfill을 넣어주면 다음 행의 데이터로 치환해준다.

import seaborn as sns

#titanic 데이터셋
df = sns.load_dataset("titanic")

#embark_town열의 829행의 NaN데이터 출력
print(df["embark_town"][825:830])
print("\n")

#NaN데이터를 이전 데이터인 828행의 데이터로 치환
df["embark_town"].fillna(method="ffill", inplace=True)

#embark_town열 829행의 NaN데이터 출력
print(df["embark_town"][825:830])
# Out:
# 825     Queenstown
# 826    Southampton
# 827      Cherbourg
# 828     Queenstown
# 829            NaN
# Name: embark_town, dtype: object
#
#
# 825     Queenstown
# 826    Southampton
# 827      Cherbourg
# 828     Queenstown
# 829     Queenstown
# Name: embark_town, dtype: object

# %% [markdown]
# ===============================================================================================================
#
#     중복 데이터 처리
#
# ===============================================================================================================

# %%
#중복 데이터 확인
#duplicated()메소드를 사용하면 각 행의 중복 여부를 나타내는 불린 시리즈를 반환한다.
#중복이면 True, 중복이 없으면 False

import pandas as pd

df = pd.DataFrame(
    {
        "c1":["a","a","b","a","b"],
        "c2":[1,1,1,2,2],
        "c3":[1,1,2,2,2]
    }
)
print(df)
print("\n")

#데이터프레임 전체 행 데이터 중에서 중복 찾기
df_dup=df.duplicated()
print(df_dup)
print("\n")

#데이터프레임의 특정 열 데이터에서 중복값 찾기
col_dup = df["c2"].duplicated()
print(col_dup)
# Out:
#   c1  c2  c3
# 0  a   1   1
# 1  a   1   1
# 2  b   1   2
# 3  a   2   2
# 4  b   2   2
#
#
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
#중복 데이터 제거
#중복 데이터를 제거하는 함수로 drop_duplicates()를 사용하고 inplace=True로 적용한다.

import pandas as pd

df = pd.DataFrame(
    {
        "c1":["a","a","b","a","b"],
        "c2":[1,1,1,2,2],
        "c3":[1,1,2,2,2]
    }
)
print(df)
print("\n")

#데이터프레임에서 중복 행 제거 
df_dropdup = df.drop_duplicates()
print(df_dropdup)
print("\n")

#c2,c3 열 기준으로 중복 제거하기
col_dropdup = df.drop_duplicates(subset=["c2","c3"])
print(col_dropdup)
# Out:
#   c1  c2  c3
# 0  a   1   1
# 1  a   1   1
# 2  b   1   2
# 3  a   2   2
# 4  b   2   2
#
#
#   c1  c2  c3
# 0  a   1   1
# 2  b   1   2
# 3  a   2   2
# 4  b   2   2
#
#
#   c1  c2  c3
# 0  a   1   1
# 2  b   1   2
# 3  a   2   2

# %% [markdown]
# ===============================================================================================================
#
#     데이터 표준화
#
# ===============================================================================================================

# %%
#단위 환산

import pandas as pd

df=pd.read_csv("./data/auto-mpg.csv", header=None)

#열 이름 지정
df.columns = [
    "mpg",
    "cylinders",
    "displacement",
    "horsepower",
    "weight",
    "acceleration",
    "model_year",
    "origin",
    "name"
]

#
print(df.head(3))
print("\n")

#mpg를 kpl로 변환
mpg_to_kpl = 1.60934 / 3.78541

#mpg열에 0.425를 곱한 결과를 새로운 열(kpl)에 추가
df["kpl"] = df["mpg"] * mpg_to_kpl
print(df.head())
print("\n")

#
df["kpl"] = df["kpl"].round(2)
print(df.head())
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
#
#
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
#
# ...

# %%
#자료형 변환

import pandas as pd
import numpy as np

df= pd.read_csv("./data/auto-mpg.csv")
#열 이름 지정
df.columns = [
    "mpg",
    "cylinders",
    "displacement",
    "horsepower",
    "weight",
    "acceleration",
    "model_year",
    "origin",
    "name"
]

print(df.head())
print("\n")

#각 열 자료형 확인
print(df.dtypes)
print("\n")

#horsepower 열의 고유값 확인
print(df["horsepower"].unique())
print("\n")

#누락 데이터 ("?") 삭제
#"?"을 np.nan으로 변환
df["horsepower"].replace("?",np.nan, inplace=True)
#누락 데이터 행 삭제
df.dropna(subset=["horsepower"],axis=0,inplace=True)
#문자열을 실수형으로 변환
df["horsepower"] = df["horsepower"].astype("float")

#horsepower 열의 자료형 확인
print(df["origin"].dtypes)

#horsepower 열의 고유자료형 확인
print(df["origin"].unique())

#정수형 데이터를 문자열 데이터로 변환
df["origin"].replace(
    {
        1:"USA",
        2:"EU",
        3:"JPN"
    },
    inplace=True
)

#origin열의 고유값과 자료형 확인
print(df["origin"].unique())
print(df["origin"].dtypes)

#문자열을 범주형으로 변환
df["origin"] = df["origin"].astype("category")
print(df["origin"].dtypes)

#범주형을 문자열로 다시 변환
df["origin"] = df["origin"].astype("str")
print(df["origin"].dtypes)

#model year 열의 정수형을 범주형으로 변환
df["model_year"] = df["model_year"].astype("category")
print(df["model_year"].sample(3))
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  15.0          8         350.0      165.0  3693.0          11.5          70
# 1  18.0          8         318.0      150.0  3436.0          11.0          70
# 2  16.0          8         304.0      150.0  3433.0          12.0          70
# 3  17.0          8         302.0      140.0  3449.0          10.5          70
# 4  15.0          8         429.0      198.0  4341.0          10.0          70
#
#    origin                name
# 0       1   buick skylark 320
# 1       1  plymouth satellite
# 2       1       amc rebel sst
# 3       1         ford torino
# 4       1    ford galaxie 500
#
#
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight          float64
# acceleration    float64
# model_year        int64
# origin            int64
# name             object
# dtype: object
#
#
# ...

# %% [markdown]
# ===============================================================================================================
#
#     범주형 ( 카테고리 ) 데이터 처리
#
# ===============================================================================================================

# %%
#구간분할
#데이터 분석 알고리즘에 따라서는 연속적인 데이터 보다 일정한 구간으로 분할이 효율적인 경우가 있다.

import pandas as pd
import numpy as np

df= pd.read_csv("./data/auto-mpg.csv")
#열 이름 지정
df.columns = [
    "mpg",
    "cylinders",
    "displacement",
    "horsepower",
    "weight",
    "acceleration",
    "model_year",
    "origin",
    "name"
]

print(df.head())
print("\n")

#"?"을 np.nan으로 변환
df["horsepower"].replace("?",np.nan, inplace=True)
df.dropna(subset=["horsepower"],axis=0,inplace=True)
df["horsepower"] = df["horsepower"].astype("float")

#np.histogram() 함수로 3개의bin으로 구분할 경계값 리스트 구하기
count , bin_dividers = np.histogram(df["horsepower"], bins=3)
print(bin_dividers)

#3개의 bin 이름 지정
bin_names = ["저출력","보통출력","고출력"]

#pd.cut 함수로 각 데이터를 3개의 bin에 할당
df["hp_bin"] = pd.cut(
    x = df["horsepower"],
    bins=bin_dividers,
    labels=bin_names,
    include_lowest=True
)

#horsepower 열, hp_bin 열의 첫 15행 출력
print(df[["horsepower","hp_bin"]].head(15))
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  15.0          8         350.0      165.0  3693.0          11.5          70
# 1  18.0          8         318.0      150.0  3436.0          11.0          70
# 2  16.0          8         304.0      150.0  3433.0          12.0          70
# 3  17.0          8         302.0      140.0  3449.0          10.5          70
# 4  15.0          8         429.0      198.0  4341.0          10.0          70
#
#    origin                name
# 0       1   buick skylark 320
# 1       1  plymouth satellite
# 2       1       amc rebel sst
# 3       1         ford torino
# 4       1    ford galaxie 500
#
#
# [ 46.         107.33333333 168.66666667 230.        ]
#     horsepower hp_bin
# 0        165.0   보통출력
# 1        150.0   보통출력
# 2        150.0   보통출력
# 3        140.0   보통출력
# 4        198.0    고출력
# 5        220.0    고출력
# 6        215.0    고출력
# 7        225.0    고출력
# 8        190.0    고출력
# ...

# %%
#더미 변수

import pandas as pd
import numpy as np
from sklearn import preprocessing

df= pd.read_csv("./data/auto-mpg.csv")
#열 이름 지정
df.columns = [
    "mpg",
    "cylinders",
    "displacement",
    "horsepower",
    "weight",
    "acceleration",
    "model_year",
    "origin",
    "name"
]

print(df.head())
print("\n")

#"?"을 np.nan으로 변환
df["horsepower"].replace("?",np.nan, inplace=True)
df.dropna(subset=["horsepower"],axis=0,inplace=True)
df["horsepower"] = df["horsepower"].astype("float")

#np.histogram() 함수로 3개의bin으로 구분할 경계값 리스트 구하기
count , bin_dividers = np.histogram(df["horsepower"], bins=3)
print(bin_dividers)

#3개의 bin 이름 지정
bin_names = ["저출력","보통출력","고출력"]

#pd.cut 함수로 각 데이터를 3개의 bin에 할당
df["hp_bin"] = pd.cut(
    x = df["horsepower"],
    bins=bin_dividers,
    labels=bin_names,
    include_lowest=True
)

horsepower_dummies = pd.get_dummies(df["hp_bin"])
print(horsepower_dummies.head(15))

#전저리를 위한 encoder객체 만들기
label_encoder = preprocessing.LabelEncoder()
onehot_encoder = preprocessing.OneHotEncoder()

# label encoder로 문자열 범주를 숫자형 범주로 변환
onehot_labeled = label_encoder.fit_transform(df["hp_bin"].head(15))
print(onehot_labeled)
print(type(onehot_labeled))

# 2차원 행렬로 변경
onehot_reshaped = onehot_labeled.reshape(len(onehot_labeled), 1)
print(onehot_reshaped)
print(type(onehot_reshaped))

#희소행렬로 변환
onehot_fitted = onehot_encoder.fit_transform(onehot_reshaped)
print(onehot_fitted)
print(type(onehot_fitted))
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  15.0          8         350.0      165.0  3693.0          11.5          70
# 1  18.0          8         318.0      150.0  3436.0          11.0          70
# 2  16.0          8         304.0      150.0  3433.0          12.0          70
# 3  17.0          8         302.0      140.0  3449.0          10.5          70
# 4  15.0          8         429.0      198.0  4341.0          10.0          70
#
#    origin                name
# 0       1   buick skylark 320
# 1       1  plymouth satellite
# 2       1       amc rebel sst
# 3       1         ford torino
# 4       1    ford galaxie 500
#
#
# [ 46.         107.33333333 168.66666667 230.        ]
#     저출력  보통출력  고출력
# 0     0     1    0
# 1     0     1    0
# 2     0     1    0
# 3     0     1    0
# 4     0     0    1
# 5     0     0    1
# 6     0     0    1
# 7     0     0    1
# 8     0     0    1
# 9     0     0    1
# 10    0     1    0
# ...

# %%
#정규화 - 

import pandas as pd
import numpy as np
from sklearn import preprocessing

df= pd.read_csv("./data/auto-mpg.csv")
#열 이름 지정
df.columns = [
    "mpg",
    "cylinders",
    "displacement",
    "horsepower",
    "weight",
    "acceleration",
    "model_year",
    "origin",
    "name"
]

print(df.head())
print("\n")

#"?"을 np.nan으로 변환
df["horsepower"].replace("?",np.nan, inplace=True)
df.dropna(subset=["horsepower"],axis=0,inplace=True)
df["horsepower"] = df["horsepower"].astype("float")

#horsepower열의 통계요약 정보로 최대값 max확인
print(df.horsepower.describe())
print("\n")

#정규화
min_x = df.horsepower - df.horsepower.min()
min_max = df.horsepower.max() - df.horsepower.min()
df.horsepower = min_x / min_max

print(df.horsepower.head())
print("\n")
print(df.horsepower.describe())
print("\n")
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  15.0          8         350.0      165.0  3693.0          11.5          70
# 1  18.0          8         318.0      150.0  3436.0          11.0          70
# 2  16.0          8         304.0      150.0  3433.0          12.0          70
# 3  17.0          8         302.0      140.0  3449.0          10.5          70
# 4  15.0          8         429.0      198.0  4341.0          10.0          70
#
#    origin                name
# 0       1   buick skylark 320
# 1       1  plymouth satellite
# 2       1       amc rebel sst
# 3       1         ford torino
# 4       1    ford galaxie 500
#
#
# count    391.000000
# mean     104.404092
# std       38.518732
# min       46.000000
# 25%       75.000000
# 50%       93.000000
# 75%      125.000000
# max      230.000000
# Name: horsepower, dtype: float64
#
#
# 0    0.646739
# 1    0.565217
# 2    0.565217
# 3    0.510870
# 4    0.826087
# ...

# %% [markdown]
# ===============================================================================================================
#
#     시계열 데이터
#
# ===============================================================================================================

# %%
#다른 자료형을 시계열 데이터로 변환 - 문자열을 timestamp로 변환

import pandas as pd

df = pd.read_csv("./data/stock-data.csv")

print(df.head())
print("\n")
print(df.info())
print("\n")

#문자열 데이터(시리즈 객체)를 판다스 timestamp로 변환
df["new_Date"] = pd.to_datetime(df["Date"])

#데이터 내용 및 자료형 확인
print(df.head())
print("\n")
print(df.info())
print("\n")
print(df["new_Date"][0])

#시계열 값으로 변환된 열을 새로운 행 인덱스로 지정
#기존 날짜열은 삭제
df.set_index("new_Date", inplace=True)
df.drop("Date",axis=1,inplace=True)

#데이터 내용 및 자료형 확인
print(df.head())
print("\n")
print(df.info())
# Out:
#          Date  Close  Start   High    Low  Volume
# 0  2018-07-02  10100  10850  10900  10000  137977
# 1  2018-06-29  10700  10550  10900   9990  170253
# 2  2018-06-28  10400  10900  10950  10150  155769
# 3  2018-06-27  10900  10800  11050  10500  133548
# 4  2018-06-26  10800  10900  11000  10700   63039
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    20 non-null     object
#  1   Close   20 non-null     int64
#  2   Start   20 non-null     int64
#  3   High    20 non-null     int64
#  4   Low     20 non-null     int64
#  5   Volume  20 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.1+ KB
# None
#
#
#          Date  Close  Start   High    Low  Volume   new_Date
# 0  2018-07-02  10100  10850  10900  10000  137977 2018-07-02
# 1  2018-06-29  10700  10550  10900   9990  170253 2018-06-29
# ...

# %%
#다른 자료형을 시계열 데이터로 변환 - timestamp로을 period로 변환

import pandas as pd

dates = [
    "2019-01-01",
    "2020-03-01",
    "2021-06-01"
]

#문자열의 배열(시리즈 객체)을 판다스 Timestamp로 변환
ts_dates = pd.to_datetime(dates)
print(ts_dates)
print("\n")

#Timestamp를 Period로 변환
pr_day = ts_dates.to_period(freq="D")
print("pr_day:",pr_day)
pr_month = ts_dates.to_period(freq="M")
print("pr_month:",pr_month)
pr_year = ts_dates.to_period(freq="Y")
print("pr_year:",pr_year)
# Out:
# DatetimeIndex(['2019-01-01', '2020-03-01', '2021-06-01'], dtype='datetime64[ns]', freq=None)
#
#
# pr_day: PeriodIndex(['2019-01-01', '2020-03-01', '2021-06-01'], dtype='period[D]', freq='D')
# pr_month: PeriodIndex(['2019-01', '2020-03', '2021-06'], dtype='period[M]', freq='M')
# pr_year: PeriodIndex(['2019', '2020', '2021'], dtype='period[A-DEC]', freq='A-DEC')

# %%
#시계열 데이터 만들기 - Timestamp배열

import pandas as pd

ts_ms = pd.date_range(
    start = "2019-01-01",
    end = None,
    periods=6,
    freq="MS",
    tz="Asia/Seoul"
)

print(ts_ms)
print("\n")

#월 간격 월의 마지막 날 기준
ts_me = pd.date_range(
    "2019-01-01",
    periods=6,
    freq="M",
    tz="Asia/Seoul"
)

print(ts_me)
print("\n")

ts_3m = pd.date_range(
    "2019-01-01",
    periods=6,
    freq="3M",
    tz="Asia/Seoul"
)

print(ts_3m)
print("\n")
# Out:
# DatetimeIndex(['2019-01-01 00:00:00+09:00', '2019-02-01 00:00:00+09:00',
#                '2019-03-01 00:00:00+09:00', '2019-04-01 00:00:00+09:00',
#                '2019-05-01 00:00:00+09:00', '2019-06-01 00:00:00+09:00'],
#               dtype='datetime64[ns, Asia/Seoul]', freq='MS')
#
#
# DatetimeIndex(['2019-01-31 00:00:00+09:00', '2019-02-28 00:00:00+09:00',
#                '2019-03-31 00:00:00+09:00', '2019-04-30 00:00:00+09:00',
#                '2019-05-31 00:00:00+09:00', '2019-06-30 00:00:00+09:00'],
#               dtype='datetime64[ns, Asia/Seoul]', freq='M')
#
#
# DatetimeIndex(['2019-01-31 00:00:00+09:00', '2019-04-30 00:00:00+09:00',
#                '2019-07-31 00:00:00+09:00', '2019-10-31 00:00:00+09:00',
#                '2020-01-31 00:00:00+09:00', '2020-04-30 00:00:00+09:00'],
#               dtype='datetime64[ns, Asia/Seoul]', freq='3M')

# %%
#시계열 데이터 만들기 - period배열

import pandas as pd

pr_m = pd.date_range(
    start = "2019-01-01",
    end = None,
    periods=3,
    freq="M"
)

print(pr_m)
print("\n")

#
pr_h = pd.date_range(
    start = "2019-01-01",
    end = None,
    periods=3,
    freq="H"
)

print(pr_h)
print("\n")

pr_2h = pd.date_range(
    start = "2019-01-01",
    end = None,
    periods=3,
    freq="2H"
)

print(pr_2h)
print("\n")
# Out:
# DatetimeIndex(['2019-01-31', '2019-02-28', '2019-03-31'], dtype='datetime64[ns]', freq='M')
#
#
# DatetimeIndex(['2019-01-01 00:00:00', '2019-01-01 01:00:00',
#                '2019-01-01 02:00:00'],
#               dtype='datetime64[ns]', freq='H')
#
#
# DatetimeIndex(['2019-01-01 00:00:00', '2019-01-01 02:00:00',
#                '2019-01-01 04:00:00'],
#               dtype='datetime64[ns]', freq='2H')

# %%
#시계열 데이터 - 날짜와 데이터 분리

import pandas as pd

df = pd.read_csv("./data/stock-data.csv")

print(df.head())
print("\n")
print(df.info())
print("\n")

#문자열 데이터(시리즈 객체)를 판다스 timestamp로 변환
df["new_Date"] = pd.to_datetime(df["Date"])

#데이터 내용 및 자료형 확인
print(df.head())
print("\n")
print(df.info())
print("\n")

#dt 속성을 이용하여 new_Date 열의 연 월 일 정보를 년 월 일 각각 구분
df["Year"] = df["new_Date"].dt.year
df["Month"] = df["new_Date"].dt.month
df["Day"] = df["new_Date"].dt.day
print(df.head())

#Timestamp를 period로 변환하여 연-월-일 표기 변경
df["Date_yr"]=df["new_Date"].dt.to_period(freq="A")
df["Date_m"]=df["new_Date"].dt.to_period(freq="M")
print(df.head())
# Out:
#          Date  Close  Start   High    Low  Volume
# 0  2018-07-02  10100  10850  10900  10000  137977
# 1  2018-06-29  10700  10550  10900   9990  170253
# 2  2018-06-28  10400  10900  10950  10150  155769
# 3  2018-06-27  10900  10800  11050  10500  133548
# 4  2018-06-26  10800  10900  11000  10700   63039
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    20 non-null     object
#  1   Close   20 non-null     int64
#  2   Start   20 non-null     int64
#  3   High    20 non-null     int64
#  4   Low     20 non-null     int64
#  5   Volume  20 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.1+ KB
# None
#
#
#          Date  Close  Start   High    Low  Volume   new_Date
# 0  2018-07-02  10100  10850  10900  10000  137977 2018-07-02
# 1  2018-06-29  10700  10550  10900   9990  170253 2018-06-29
# ...

# %%
#시계열 데이터 - 날짜 인덱스 사용

import pandas as pd

df = pd.read_csv("./data/stock-data.csv")

print(df.head())
print("\n")
print(df.info())
print("\n")

#문자열 데이터(시리즈 객체)를 판다스 timestamp로 변환
df["new_Date"] = pd.to_datetime(df["Date"])

df["new_Date"] = pd.to_datetime(df["Date"])
df.set_index("new_Date", inplace=True)

print(df.head())
print("\n")
print(df.info())
print("\n")

#
df_y = df["2018"]
print(df_y)
print("\n")

df_ym = df.loc["2018-07"]
print(df_y)
print("\n")
df_ym_cols = df.loc["2018-07","Start":"High"] 
print(df_ym_cols)
print("\n")
df_ymd = df.loc["2018-07-02"]
print(df_ymd)
print("\n")
df_ymd_range = df["2018-06-25":"2018-06-20"]
print(df_ymd_range)
print("\n")

#시간 간격 계산
today = pd.to_datetime("2018-12-25")
df["time_delta"] = today - df.index
df.set_index("time_delta",inplace=True)
df_180 = df["180 days":"189 days"]
print(df_180)
# Out:
#          Date  Close  Start   High    Low  Volume
# 0  2018-07-02  10100  10850  10900  10000  137977
# 1  2018-06-29  10700  10550  10900   9990  170253
# 2  2018-06-28  10400  10900  10950  10150  155769
# 3  2018-06-27  10900  10800  11050  10500  133548
# 4  2018-06-26  10800  10900  11000  10700   63039
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    20 non-null     object
#  1   Close   20 non-null     int64
#  2   Start   20 non-null     int64
#  3   High    20 non-null     int64
#  4   Low     20 non-null     int64
#  5   Volume  20 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.1+ KB
# None
#
#
#                   Date  Close  Start   High    Low  Volume
# new_Date
# 2018-07-02  2018-07-02  10100  10850  10900  10000  137977
# 2018-06-29  2018-06-29  10700  10550  10900   9990  170253
# ...

# %% [markdown]
# ===============================================================================================================
#
#     함수 매핑
#
# ===============================================================================================================

# %%
#개별원소에 함수 매핑 - 시리즈에 함수 매핑

import seaborn as sns

titanic = sns.load_dataset("titanic")
df= titanic.loc[:, ["age","fare"]]
df["ten"] = 10
print(df.head())
print("\n")

#사용자 함수 정의
def add_10(n):
    return n +10

def add_two_obj(a,b):
    return a + b

print(add_10(10))
print(add_two_obj(10,10))

#시리즈 객체에 적용
sr1 = df["age"].apply(add_10)
print(sr1.head())
print("\n")

#
sr2 = df["age"].apply(add_two_obj, b=10)
print(sr2.head())
print("\n")

#
sr3 = df["age"].apply(lambda x: add_10(x))
print(sr3.head())
# Out:
#     age     fare  ten
# 0  22.0   7.2500   10
# 1  38.0  71.2833   10
# 2  26.0   7.9250   10
# 3  35.0  53.1000   10
# 4  35.0   8.0500   10
# 20
# 20
# 0    32.0
# 1    48.0
# 2    36.0
# 3    45.0
# 4    45.0
# Name: age, dtype: float64
#
#
# 0    32.0
# 1    48.0
# 2    36.0
# 3    45.0
# 4    45.0
# Name: age, dtype: float64
#
#
# 0    32.0
# 1    48.0
# 2    36.0
# 3    45.0
# 4    45.0
# Name: age, dtype: float64

# %%
#개별원소에 함수 매핑 - 데이터프레임에 함수 매핑

import seaborn as sns

titanic = sns.load_dataset("titanic")
df= titanic.loc[:, ["age","fare"]]
df["ten"] = 10
print(df.head())
print("\n")

#사용자 함수 정의
def add_10(n):
    return n + 10

#데이터프레임에 add_10 함수를 매핑
df_map = df.applymap(add_10)
print(df_map.head())
# Out:
#     age     fare  ten
# 0  22.0   7.2500   10
# 1  38.0  71.2833   10
# 2  26.0   7.9250   10
# 3  35.0  53.1000   10
# 4  35.0   8.0500   10
#
#
#     age     fare  ten
# 0  32.0  17.2500   20
# 1  48.0  81.2833   20
# 2  36.0  17.9250   20
# 3  45.0  63.1000   20
# 4  45.0  18.0500   20

# %%
#시리즈 객체에 함수 매핑 - 데이터프레임의 각 열에 함수매핑

import seaborn as sns

titanic = sns.load_dataset("titanic")
df= titanic.loc[:, ["age","fare"]]
df["ten"] = 10
print(df.head())
print("\n")

#사용자 정의 함수
def missing_value(series):
    return series.isnull()

def min_max(x):
    return x.min()-x.max()

#데이터프레임에 apply메소드 적용
res = df.apply(missing_value, axis=0)
print(res.head())
print("\n")
print(type(res))

res = df.apply(min_max)
print(res.head())
print("\n")
print(type(res))
# Out:
#     age     fare  ten
# 0  22.0   7.2500   10
# 1  38.0  71.2833   10
# 2  26.0   7.9250   10
# 3  35.0  53.1000   10
# 4  35.0   8.0500   10
#
#
#      age   fare    ten
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False
# 4  False  False  False
#
#
# <class 'pandas.core.frame.DataFrame'>
# age     -79.5800
# fare   -512.3292
# ten       0.0000
# dtype: float64
#
#
# <class 'pandas.core.series.Series'>

# %%
#시리즈 객체에 함수 매핑 - 데이터프레임의 각 행에 함수매핑

import seaborn as sns

titanic = sns.load_dataset("titanic")
df= titanic.loc[:, ["age","fare"]]
df["ten"] = 10
print(df.head())
print("\n")

#사용자 정의 함수
def add_two_obj(a,b):
    return a+ b

#데이터프레임의 2개열에 적용
# x=df, a=df["age"], b=df["ten"]
df["add"] = df.apply(lambda x: add_two_obj(x["age"] , x["ten"]), axis=1)
print(df.head())
# Out:
#     age     fare  ten
# 0  22.0   7.2500   10
# 1  38.0  71.2833   10
# 2  26.0   7.9250   10
# 3  35.0  53.1000   10
# 4  35.0   8.0500   10
#
#
#     age     fare  ten   add
# 0  22.0   7.2500   10  32.0
# 1  38.0  71.2833   10  48.0
# 2  26.0   7.9250   10  36.0
# 3  35.0  53.1000   10  45.0
# 4  35.0   8.0500   10  45.0

# %%
#데이터프레임 객체에 함수 매핑

import seaborn as sns

titanic = sns.load_dataset("titanic")
df= titanic.loc[:, ["age","fare"]]
df["ten"] = 10
print(df.head())
print("\n")

#사용자 정의 함수
def missing_value(x):
    return x.isnull()

def missing_count(x):
    return missing_value(x).sum()

def total_number_missing(x):
    return missing_count(x).sum()

res = df.pipe(missing_value)
print(res.head())
print(type(res))
print("\n")

res = df.pipe(missing_count)
print(res.head())
print(type(res))
print("\n")

res = df.pipe(total_number_missing)
print(res)
print(type(res))
print("\n")
# Out:
#     age     fare  ten
# 0  22.0   7.2500   10
# 1  38.0  71.2833   10
# 2  26.0   7.9250   10
# 3  35.0  53.1000   10
# 4  35.0   8.0500   10
#
#
#      age   fare    ten
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False
# 4  False  False  False
# <class 'pandas.core.frame.DataFrame'>
#
#
# age     177
# fare      0
# ten       0
# dtype: int64
# <class 'pandas.core.series.Series'>
#
#
# 177
# <class 'numpy.int64'>

# %% [markdown]
# ===============================================================================================================
#
#     열 재구성
#
# ===============================================================================================================

# %%
#열 순서 변경

import seaborn as sns

titanic = sns.load_dataset("titanic")
df= titanic.loc[0:4, "survived":"age"]
print(df)
print("\n")

#열 이름의 리스트 만들기
columns = list(df.columns.values)
print(columns)
print("\n")

#열 이름을 알파벳 순서로 정렬
columns_sorted = sorted(columns)
df_sorted = df[columns_sorted]
print(df_sorted)
print("\n")

#열 이름을 기존 순서의 정 반대 역순으로 정렬
columns_reversed = list(reversed(columns))
df_reversed = df[columns_reversed]
print(df_reversed)
print("\n")

#열 이름을 사용자가 정의한 임의의 순서로 재배치
columns_customed = [ "pclass", "sex", "age", "survived" ]
df_customed = df[columns_customed]
print(df_customed)
print("\n")
# Out:
#    survived  pclass     sex   age
# 0         0       3    male  22.0
# 1         1       1  female  38.0
# 2         1       3  female  26.0
# 3         1       1  female  35.0
# 4         0       3    male  35.0
#
#
# ['survived', 'pclass', 'sex', 'age']
#
#
#     age  pclass     sex  survived
# 0  22.0       3    male         0
# 1  38.0       1  female         1
# 2  26.0       3  female         1
# 3  35.0       1  female         1
# 4  35.0       3    male         0
#
#
#     age     sex  pclass  survived
# 0  22.0    male       3         0
# 1  38.0  female       1         1
# 2  26.0  female       3         1
# 3  35.0  female       1         1
# 4  35.0    male       3         0
#
#
#    pclass     sex   age  survived
# 0       3    male  22.0         0
# 1       1  female  38.0         1
# 2       3  female  26.0         1
# 3       1  female  35.0         1
# 4       3    male  35.0         0

# %%
#열 분리

import pandas as pd

df = pd.read_excel("./data/stock.xlsx",engine="openpyxl")

print(df.head())
print("\n")
print(df.dtypes)
print("\n")

#연월일 데이터 분리하기
df["연월일"] = df["연월일"].astype("str")
dates = df["연월일"].str.split("-")
print(dates.head())

#분리된 정보를 각각 새로운 열에 담아 df 추가하기
df["연"] = dates.str.get(0)
df["월"] = dates.str.get(1)
df["일"] = dates.str.get(2)
print(df.head())
# Out:
#          연월일   당일종가  전일종가     시가     고가     저가     거래량
# 0 2018-07-02  10100   600  10850  10900  10000  137977
# 1 2018-06-29  10700   300  10550  10900   9990  170253
# 2 2018-06-28  10400   500  10900  10950  10150  155769
# 3 2018-06-27  10900   100  10800  11050  10500  133548
# 4 2018-06-26  10800   350  10900  11000  10700   63039
#
#
# 연월일     datetime64[ns]
# 당일종가             int64
# 전일종가             int64
# 시가               int64
# 고가               int64
# 저가               int64
# 거래량              int64
# dtype: object
#
#
# 0    [2018, 07, 02]
# 1    [2018, 06, 29]
# 2    [2018, 06, 28]
# 3    [2018, 06, 27]
# 4    [2018, 06, 26]
# Name: 연월일, dtype: object
#           연월일   당일종가  전일종가     시가     고가     저가     거래량     연   월   일
# 0  2018-07-02  10100   600  10850  10900  10000  137977  2018  07  02
# 1  2018-06-29  10700   300  10550  10900   9990  170253  2018  06  29
# 2  2018-06-28  10400   500  10900  10950  10150  155769  2018  06  28
# ...

# %% [markdown]
# ===============================================================================================================
#
#     필터링
#
# ===============================================================================================================

# %%
#불린 인덱싱

import seaborn as sns
titanic = sns.load_dataset("titanic")

#나이가 10대인 승객만
mask_10 = (titanic.age >= 10) & (titanic.age < 20)
df_teenage = titanic.loc[mask_10, : ]
print(df_teenage.head())

#나이가 10세 미만이고 여성인 승객
mask_x = (titanic.age < 10) & (titanic.sex == "female")
df_teenage_under = titanic.loc[mask_x, : ]
print(df_teenage_under.head())

#나이가 10세미만 또는 60세 이상인 승객의 age,sex,alone 열만 출력
mask_x = (titanic.age < 10) | (titanic.age >= 60)
df_teenage_under_and_old = titanic.loc[mask_x, ["age", "sex" ,"alone"] ]
print(df_teenage_under_and_old.head())
# Out:
#     survived  pclass     sex   age  sibsp  parch      fare  ...   class    who adult_male  deck  embark_town alive  alone
# 9          1       2  female  14.0      1      0   30.0708  ...  Second  child      False   NaN    Cherbourg   yes  False
# 14         0       3  female  14.0      0      0    7.8542  ...   Third  child      False   NaN  Southampton    no   True
# 22         1       3  female  15.0      0      0    8.0292  ...   Third  child      False   NaN   Queenstown   yes   True
# 27         0       1    male  19.0      3      2  263.0000  ...   First    man       True     C  Southampton    no  False
# 38         0       3  female  18.0      2      0   18.0000  ...   Third  woman      False   NaN  Southampton    no  False
#
# [5 rows x 15 columns]
#      survived  pclass     sex  age  sibsp  parch     fare  ...   class    who adult_male  deck  embark_town alive  alone
# ...

# %%
#isin() 메소드 활용

import seaborn as sns
titanic = sns.load_dataset("titanic")

import pandas as pd

#IPython 디스플레이 설정 변경 - 출력할 최대 열의 개수
pd.set_option("display.max_columns",10)

#함께 탑승한 형제 또는 배우자 수가 3,4,5인 승객만 따로 추출
mask_3 = titanic["sibsp"] == 3
mask_4 = titanic["sibsp"] == 4
mask_5 = titanic["sibsp"] == 5

df_boolean = titanic[ mask_3 |mask_4 |mask_5 ]
print(df_boolean.head())

#isin() 메소드 활용하여 동일한 조건으로 추출
isin_filter = titanic["sibsp"].isin([3,4,5])
df_isin = titanic[isin_filter]
print(df_isin.head())
# Out:
#     survived  pclass     sex   age  sibsp  ...  adult_male  deck  embark_town  \
# 7          0       3    male   2.0      3  ...       False   NaN  Southampton
# 16         0       3    male   2.0      4  ...       False   NaN   Queenstown
# 24         0       3  female   8.0      3  ...       False   NaN  Southampton
# 27         0       1    male  19.0      3  ...        True     C  Southampton
# 50         0       3    male   7.0      4  ...       False   NaN  Southampton
#
#    alive  alone
# 7     no  False
# 16    no  False
# 24    no  False
# 27    no  False
# 50    no  False
#
# [5 rows x 15 columns]
#     survived  pclass     sex   age  sibsp  ...  adult_male  deck  embark_town  \
# 7          0       3    male   2.0      3  ...       False   NaN  Southampton
# 16         0       3    male   2.0      4  ...       False   NaN   Queenstown
# 24         0       3  female   8.0      3  ...       False   NaN  Southampton
# ...
